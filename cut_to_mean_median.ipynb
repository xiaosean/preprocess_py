# %%
import os.path
import numpy as np
import pandas as pd
from time import time

# %%
# set configure
path = "./"
filename = "Groups_ID"
relative_filename = path + filename + ".csv"
# out_filename = "output_FYSP_HTTPDR_CATG_WEEKOF_MLY_2017-04-01_aggregate"

# %%
# read revise csv file and print cost time
t0 = time()
group_df = pd.read_csv(relative_filename, error_bad_lines=False, usecols = ["MINING_DW_SUBSCR_NO", "Groups"])
print("time for read csv: %.2f" % (time()-t0))
# Out:
# time for read csv: 0.57

# %%
group_df.head()
# Out:
#    MINING_DW_SUBSCR_NO               Groups
# 0          10000000008  InstantMessage-High
# 1          10000000013   InstantMessage-Low
# 2          10000000020  InstantMessage-High
# 3          10000000027   InstantMessage-Low
# 4          10000000028   InstantMessage-Low

# %%
len(group_df)
# Out:
# 1882629

# %%
category_list = group_df.groupby("Groups").count()

# %%
category_list
# Out:
#                            MINING_DW_SUBSCR_NO
# Groups
# Adult                                    54272
# Game                                     87526
# HomeLife                                 74912
# Infrequent Internet User                144850
# InstantMessage-High                     424384
# InstantMessage-Low                      431647
# Map                                     103733
# News                                     57131
# No significant preference               266772
# Portal                                   98511
# Social-media                            138891

# %%
category_list = list(category_list.index)

# %%
# set configure
path = "./CDR_FINAL/"
filename = "0703normalize_65_cols"
relative_filename = path + filename + ".csv"
# out_filename = "output_FYSP_HTTPDR_CATG_WEEKOF_MLY_2017-04-01_aggregate"

# %%
# copy a dataframe without date and id
user_df = pd.read_csv(relative_filename, error_bad_lines=False)

# %%
user_df.head()
# Out:
#    MINING_DW_SUBSCR_NO  VOICE_HOUR_0_TIME  VOICE_HOUR_1_TIME  \
# 0           8134330931                0.0                0.0
# 1           2118544651                0.0                0.0
# 2          10000337216                0.0                0.0
# 3           3133428916                0.0                0.0
# 4           3119268553                0.0                0.0
#
#    VOICE_HOUR_2_TIME  VOICE_HOUR_3_TIME  VOICE_HOUR_4_TIME  VOICE_HOUR_5_TIME  \
# 0                0.0                0.0                0.0              0.000
# 1                0.0                0.0                0.0              0.000
# 2                0.0                0.0                0.0              0.003
# 3                0.0                0.0                0.0              0.000
# 4                0.0                0.0                0.0              0.000
#
#    VOICE_HOUR_6_TIME  VOICE_HOUR_7_TIME  VOICE_HOUR_8_TIME       ...         \
# ...

# %%
list(user_df.columns)
# Out:
# ['MINING_DW_SUBSCR_NO',
#  'VOICE_HOUR_0_TIME',
#  'VOICE_HOUR_1_TIME',
#  'VOICE_HOUR_2_TIME',
#  'VOICE_HOUR_3_TIME',
#  'VOICE_HOUR_4_TIME',
#  'VOICE_HOUR_5_TIME',
#  'VOICE_HOUR_6_TIME',
#  'VOICE_HOUR_7_TIME',
#  'VOICE_HOUR_8_TIME',
#  'VOICE_HOUR_9_TIME',
#  'VOICE_HOUR_10_TIME',
#  'VOICE_HOUR_11_TIME',
#  'VOICE_HOUR_12_TIME',
#  'VOICE_HOUR_13_TIME',
#  'VOICE_HOUR_14_TIME',
#  'VOICE_HOUR_15_TIME',
#  'VOICE_HOUR_16_TIME',
#  'VOICE_HOUR_17_TIME',
#  'VOICE_HOUR_18_TIME',
#  'VOICE_HOUR_19_TIME',
#  'VOICE_HOUR_20_TIME',
#  'VOICE_HOUR_21_TIME',
#  'VOICE_HOUR_22_TIME',
#  'VOICE_HOUR_23_TIME',
#  'voice_monthly_sum',
#  'VOICE_HOUR_MON_TIME',
#  'VOICE_HOUR_TUE_TIME',
#  'VOICE_HOUR_WED_TIME',
#  'VOICE_HOUR_THU_TIME',
#  'VOICE_HOUR_FRI_TIME',
#  'VOICE_HOUR_SAT_TIME',
#  'VOICE_HOUR_SUN_TIME',
#  'DNA_Monday',
#  'DNA_Tuesday',
#  'DNA_Wednesday',
#  'DNA_Thursday',
#  'DNA_Friday',
#  'DNA_Saturday',
#  'DNA_Sunday',
#  'DNA_HOUR_0_CNT',
#  'DNA_HOUR_1_CNT',
# ...

# %%
wants_col = ['MINING_DW_SUBSCR_NO',
 'VOICE_HOUR_0_TIME',
 'VOICE_HOUR_1_TIME',
 'VOICE_HOUR_2_TIME',
 'VOICE_HOUR_3_TIME',
 'VOICE_HOUR_4_TIME',
 'VOICE_HOUR_5_TIME',
 'VOICE_HOUR_6_TIME',
 'VOICE_HOUR_7_TIME',
 'VOICE_HOUR_8_TIME',
 'VOICE_HOUR_9_TIME',
 'VOICE_HOUR_10_TIME',
 'VOICE_HOUR_11_TIME',
 'VOICE_HOUR_12_TIME',
 'VOICE_HOUR_13_TIME',
 'VOICE_HOUR_14_TIME',
 'VOICE_HOUR_15_TIME',
 'VOICE_HOUR_16_TIME',
 'VOICE_HOUR_17_TIME',
 'VOICE_HOUR_18_TIME',
 'VOICE_HOUR_19_TIME',
 'VOICE_HOUR_20_TIME',
 'VOICE_HOUR_21_TIME',
 'VOICE_HOUR_22_TIME',
 'VOICE_HOUR_23_TIME',
 'DNA_HOUR_0_CNT',
 'DNA_HOUR_1_CNT',
 'DNA_HOUR_2_CNT',
 'DNA_HOUR_3_CNT',
 'DNA_HOUR_4_CNT',
 'DNA_HOUR_5_CNT',
 'DNA_HOUR_6_CNT',
 'DNA_HOUR_7_CNT',
 'DNA_HOUR_8_CNT',
 'DNA_HOUR_9_CNT',
 'DNA_HOUR_10_CNT',
 'DNA_HOUR_11_CNT',
 'DNA_HOUR_12_CNT',
 'DNA_HOUR_13_CNT',
 'DNA_HOUR_14_CNT',
 'DNA_HOUR_15_CNT',
 'DNA_HOUR_16_CNT',
 'DNA_HOUR_17_CNT',
 'DNA_HOUR_18_CNT',
 'DNA_HOUR_19_CNT',
 'DNA_HOUR_20_CNT',
 'DNA_HOUR_21_CNT',
 'DNA_HOUR_22_CNT',
 'DNA_HOUR_23_CNT']

# %%
user_df = user_df[wants_col]

# %%
user_df.head()
# Out:
#    MINING_DW_SUBSCR_NO  VOICE_HOUR_0_TIME  VOICE_HOUR_1_TIME  \
# 0           8134330931                0.0                0.0
# 1           2118544651                0.0                0.0
# 2          10000337216                0.0                0.0
# 3           3133428916                0.0                0.0
# 4           3119268553                0.0                0.0
#
#    VOICE_HOUR_2_TIME  VOICE_HOUR_3_TIME  VOICE_HOUR_4_TIME  VOICE_HOUR_5_TIME  \
# 0                0.0                0.0                0.0              0.000
# 1                0.0                0.0                0.0              0.000
# 2                0.0                0.0                0.0              0.003
# 3                0.0                0.0                0.0              0.000
# 4                0.0                0.0                0.0              0.000
#
#    VOICE_HOUR_6_TIME  VOICE_HOUR_7_TIME  VOICE_HOUR_8_TIME       ...         \
# ...

# %%
result = pd.merge(user_df, group_df, on='MINING_DW_SUBSCR_NO', how='inner')

# %%
result.head()
# Out:
#    MINING_DW_SUBSCR_NO  VOICE_HOUR_0_TIME  VOICE_HOUR_1_TIME  \
# 0           8134330931                0.0                0.0
# 1           2118544651                0.0                0.0
# 2          10000337216                0.0                0.0
# 3           3133428916                0.0                0.0
# 4           3135493626                0.0                0.0
#
#    VOICE_HOUR_2_TIME  VOICE_HOUR_3_TIME  VOICE_HOUR_4_TIME  VOICE_HOUR_5_TIME  \
# 0                0.0                0.0                0.0              0.000
# 1                0.0                0.0                0.0              0.000
# 2                0.0                0.0                0.0              0.003
# 3                0.0                0.0                0.0              0.000
# 4                0.0                0.0                0.0              0.000
#
#    VOICE_HOUR_6_TIME  VOICE_HOUR_7_TIME  VOICE_HOUR_8_TIME  \
# 0              0.000              0.005              0.001
# ...

# %%
category_result = result.groupby("Groups")

# %%
category_result.head()
# Out:
#      MINING_DW_SUBSCR_NO  VOICE_HOUR_0_TIME  VOICE_HOUR_1_TIME  \
# 0             8134330931              0.000              0.000
# 1             2118544651              0.000              0.000
# 2            10000337216              0.000              0.000
# 3             3133428916              0.000              0.000
# 4             3135493626              0.000              0.000
# 5             3125061767              0.000              0.000
# 6             8131713026              0.002              0.181
# 7             3117930663              0.000              0.000
# 8             3133731219              0.000              0.000
# 9            10000354353              0.000              0.000
# 10            3136438041              0.000              0.000
# 11            8135618387              0.000              0.000
# 12            8136932676              0.000              0.081
# 13            3128800944              0.000              0.000
# ...

# %%
group_mean = category_result.mean()

# %%
group_mean = group_mean.drop("MINING_DW_SUBSCR_NO", axis = 1)

# %%
group_mean.head()
# Out:
#                           VOICE_HOUR_0_TIME  VOICE_HOUR_1_TIME  \
# Groups
# Adult                              0.012133           0.006055
# Game                               0.011175           0.005562
# HomeLife                           0.017502           0.008890
# Infrequent Internet User           0.005633           0.002706
# InstantMessage-High                0.013638           0.007134
#
#                           VOICE_HOUR_2_TIME  VOICE_HOUR_3_TIME  \
# Groups
# Adult                              0.003397           0.002241
# Game                               0.003059           0.002074
# HomeLife                           0.004664           0.002778
# Infrequent Internet User           0.001517           0.001122
# InstantMessage-High                0.004065           0.002722
#
#                           VOICE_HOUR_4_TIME  VOICE_HOUR_5_TIME  \
# Groups
# Adult                              0.002062           0.003119
# ...

# %%
# write to csv and no index
t0 = time()
# aggr_df.to_csv(out_filename + ".csv", index=False, encoding='utf-8')
group_mean.to_csv("category_dna_voice_means.csv", encoding='utf-8')
print("time for output csv file: %.2f" % (time()-t0))
# Out:
# time for output csv file: 0.01

# %%
group_median = category_result.median()

# %%
group_median = group_median.drop("MINING_DW_SUBSCR_NO", axis = 1)

# %%
group_median.head()
# Out:
#                           VOICE_HOUR_0_TIME  VOICE_HOUR_1_TIME  \
# Groups
# Adult                                   0.0                0.0
# Game                                    0.0                0.0
# HomeLife                                0.0                0.0
# Infrequent Internet User                0.0                0.0
# InstantMessage-High                     0.0                0.0
#
#                           VOICE_HOUR_2_TIME  VOICE_HOUR_3_TIME  \
# Groups
# Adult                                   0.0                0.0
# Game                                    0.0                0.0
# HomeLife                                0.0                0.0
# Infrequent Internet User                0.0                0.0
# InstantMessage-High                     0.0                0.0
#
#                           VOICE_HOUR_4_TIME  VOICE_HOUR_5_TIME  \
# Groups
# Adult                                   0.0                0.0
# ...

# %%
len(result)
# Out:
# 1882629

# %%
# write to csv and no index
t0 = time()
# aggr_df.to_csv(out_filename + ".csv", index=False, encoding='utf-8')
group_median.to_csv("category_dna_voice_median.csv", encoding='utf-8')
print("time for output csv file: %.2f" % (time()-t0))
# Out:
# time for output csv file: 0.01
