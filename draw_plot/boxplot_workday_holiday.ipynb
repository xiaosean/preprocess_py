# %%
import numpy as np
import pandas as pd
from time import time
from sklearn.cluster import KMeans
from pandas.computation import expressions as expr
from bokeh.charts import show, output_file, save, BoxPlot
import pprint as pp
import sys
from bokeh.palettes import Spectral11, Category10
from bokeh.layouts import row

# %%
# set configure
# path = "./CDR_NORMALIZE_CONCAT/"
path = "./CDR_ANALYZE/"
# path = "./CDR_CONCAT/"
# filename = sys.argv[1]
filename = "TABLE_4_MT_WORKDAY_AVG_TIME_COLS.csv"
# filename = "CDR_CONCAT_TABLE_4_max_min.csv"
# filename = "CDR_CONCAT_TABLE_4.csv"
relative_filename = path + filename  #+ ".csv"
# out_filename = "mds_mly_minus20160901"
# after the numeric_st_idx's number will be tranform to int64
# numeric_st_idx = 1
# n_clusters = 8

# %%
# read revise csv file and print cost time
# just load 5 data 
t0 = time()
df = pd.read_csv(relative_filename, error_bad_lines=False)
print("time for read csv: %.2f" % (time()-t0))
# Out:
# time for read csv: 0.16

# %%
# select columns
# df = df[['VOICE_MO_HOUR_0_TIME','VOICE_MO_HOUR_1_TIME','VOICE_MO_HOUR_2_TIME','VOICE_MO_HOUR_3_TIME','VOICE_MO_HOUR_4_TIME','VOICE_MO_HOUR_5_TIME','VOICE_MO_HOUR_6_TIME','VOICE_MO_HOUR_7_TIME','VOICE_MO_HOUR_8_TIME','VOICE_MO_HOUR_9_TIME','VOICE_MO_HOUR_10_TIME','VOICE_MO_HOUR_11_TIME','VOICE_MO_HOUR_12_TIME','VOICE_MO_HOUR_13_TIME','VOICE_MO_HOUR_14_TIME','VOICE_MO_HOUR_15_TIME','VOICE_MO_HOUR_16_TIME','VOICE_MO_HOUR_17_TIME','VOICE_MO_HOUR_18_TIME','VOICE_MO_HOUR_19_TIME','VOICE_MO_HOUR_20_TIME','VOICE_MO_HOUR_21_TIME','VOICE_MO_HOUR_22_TIME','VOICE_MO_HOUR_23_TIME']]
# df = df[['mo_workday_time','mo_holiday_time','mt_workday_time','mt_holiday_time']]
df = df.drop('MINING_DW_SUBSCR_NO', 1)
# drop_col_list = []
# for col in df.columns:
#     if str(col).find("TIME") == -1 and str(col).find("time") == -1:
#         drop_col_list.append(str(col))
# df = df.drop(drop_col_list, 1)

# %%
# for K in range(10, 11):
K = 10
n_clusters = K
labels_ = np.load("label_K" + str(K) + ".npy")
# data count in each cluster
cluster_result = {}
for i in range(n_clusters):
    cluster_result[i] = 0

# for l in kmeans.labels_:
for l in labels_:
    cluster_result[l] += 1
# pp.pprint(cluster_result)

df['label'] = labels_

# %%
grouped = df.groupby('label')

# %%
df
# Out:
#         VOICE_MT_workday_time_avg  VOICE_MT_holiday_time_avg  label
# 0                           684.0                      527.5      0
# 1                           607.0                      328.5      1
# 2                             0.0                        8.0      1
# 3                             2.0                        0.0      1
# 4                          1348.4                     1933.5      2
# 5                          1856.8                     3126.5      2
# 6                           224.8                      219.5      0
# 7                          2974.0                      206.0      2
# 8                           145.8                       33.5      1
# 9                          7583.2                     4796.0      3
# 10                          438.2                      385.5      0
# 11                            1.8                        0.0      1
# 12                         3836.0                     2774.0      6
# 13                        12056.4                     5175.5      2
# 14                          331.8                      773.5      0
# 15                           27.2                        0.0      1
# 16                          220.2                      413.5      2
# 17                          235.8                      282.5      1
# 18                          602.4                      183.0      0
# 19                          178.4                      200.5      1
# 20                           16.4                       56.5      1
# 21                         4475.2                     5388.5      4
# 22                           77.6                       19.5      1
# 23                          928.2                     1291.0      2
# 24                          213.0                      182.0      1
# 25                          122.2                      339.0      1
# 26                          588.2                      492.5      1
# 27                           78.4                       31.5      1
# 28                          133.0                        8.0      1
# 29                          422.8                      214.0      1
# ...                           ...                        ...    ...
# 436641                        0.0                      122.5      1
# 436642                        0.0                      213.5      1
# 436643                        0.0                      281.5      1
# 436644                        0.0                       65.5      1
# 436645                        0.0                       40.5      1
# 436646                        0.0                      218.0      1
# 436647                        0.0                        6.5      1
# 436648                        0.0                       14.0      1
# 436649                        0.0                        4.5      1
# 436650                        0.2                        0.0      1
# 436651                        0.0                       57.5      1
# 436652                      711.6                       91.5      0
# 436653                      242.8                      119.0      1
# 436654                      574.2                      410.0      0
# 436655                       64.6                      145.0      1
# 436656                      104.6                       15.0      1
# 436657                     1907.4                      878.5      2
# 436658                        0.0                       42.0      1
# 436659                      856.0                      359.5      1
# 436660                      158.0                      162.0      1
# 436661                       60.8                        0.0      1
# 436662                      122.6                      289.0      1
# 436663                      312.6                      233.0      1
# 436664                      241.4                       46.0      1
# 436665                      447.2                      462.5      6
# 436666                      675.4                      126.0      0
# 436667                     1832.8                      730.5      2
# 436668                      135.6                      342.5      1
# 436669                      188.0                       72.0      1
# 436670                        8.6                       35.0      1
#
# [436671 rows x 3 columns]

# %%
box = BoxPlot(df, values = 'VOICE_MT_holiday_time_avg', label = 'label', color = 'label')
show(box)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\core\json_encoder.py:73: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   if pd and isinstance(obj, pd.tslib.Timestamp):

# %%
boxes = []
for c in df.columns[:-1]:
    box = BoxPlot(df, values = c, label = 'label', color = 'label')
#     show(box)
    print(c)
    boxes.append(box)
show(row(boxes))
# Out:
# VOICE_MT_workday_time_avg
# VOICE_MT_holiday_time_avg

# %%
box = BoxPlot(df, values = 'VOICE_MT_workday_time_avg', label = 'label', color = 'label')
show(box)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-262f0e8b6063> in <module>()
#       1 box = BoxPlot(df, values = 'VOICE_MT_workday_time_avg', label = 'label', color = 'label')
# ----> 2 show(box)
#
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\io.py in show(obj, browser, new, notebook_handle, notebook_url)
#     281
#     282     if obj not in _state.document.roots:
# --> 283         _state.document.add_root(obj)
#     284     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     285
#
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\document.py in add_root(self, model, setter)
#     277             self._roots.append(model)
#     278         finally:
# --> 279             self._pop_all_models_freeze()
#     280         self._trigger_on_change(RootAddedEvent(self, model, setter))
#     281
#
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\document.py in _pop_all_models_freeze(self)
#    1078         self._all_models_freeze_count -= 1
#    1079         if self._all_models_freeze_count == 0:
# -> 1080             self._recompute_all_models()
#    1081
#    1082     def _recompute_all_models(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\document.py in _recompute_all_models(self)
#    1086         new_all_models_set = set()
#    1087         for r in self.roots:
# -> 1088             new_all_models_set = new_all_models_set.union(r.references())
#    1089         old_all_models_set = set(self._all_models.values())
#    1090         to_detach = old_all_models_set - new_all_models_set
#
# AttributeError: 'list' object has no attribute 'references'

# %%
df
# Out:
#         VOICE_MT_workday_time_avg  VOICE_MT_holiday_time_avg  label
# 0                           684.0                      527.5      0
# 1                           607.0                      328.5      1
# 2                             0.0                        8.0      1
# 3                             2.0                        0.0      1
# 4                          1348.4                     1933.5      2
# 5                          1856.8                     3126.5      2
# 6                           224.8                      219.5      0
# 7                          2974.0                      206.0      2
# 8                           145.8                       33.5      1
# 9                          7583.2                     4796.0      3
# 10                          438.2                      385.5      0
# 11                            1.8                        0.0      1
# 12                         3836.0                     2774.0      6
# 13                        12056.4                     5175.5      2
# 14                          331.8                      773.5      0
# 15                           27.2                        0.0      1
# 16                          220.2                      413.5      2
# 17                          235.8                      282.5      1
# 18                          602.4                      183.0      0
# 19                          178.4                      200.5      1
# 20                           16.4                       56.5      1
# 21                         4475.2                     5388.5      4
# 22                           77.6                       19.5      1
# 23                          928.2                     1291.0      2
# 24                          213.0                      182.0      1
# 25                          122.2                      339.0      1
# 26                          588.2                      492.5      1
# 27                           78.4                       31.5      1
# 28                          133.0                        8.0      1
# 29                          422.8                      214.0      1
# ...                           ...                        ...    ...
# 436641                        0.0                      122.5      1
# 436642                        0.0                      213.5      1
# 436643                        0.0                      281.5      1
# 436644                        0.0                       65.5      1
# 436645                        0.0                       40.5      1
# 436646                        0.0                      218.0      1
# 436647                        0.0                        6.5      1
# 436648                        0.0                       14.0      1
# 436649                        0.0                        4.5      1
# 436650                        0.2                        0.0      1
# 436651                        0.0                       57.5      1
# 436652                      711.6                       91.5      0
# 436653                      242.8                      119.0      1
# 436654                      574.2                      410.0      0
# 436655                       64.6                      145.0      1
# 436656                      104.6                       15.0      1
# 436657                     1907.4                      878.5      2
# 436658                        0.0                       42.0      1
# 436659                      856.0                      359.5      1
# 436660                      158.0                      162.0      1
# 436661                       60.8                        0.0      1
# 436662                      122.6                      289.0      1
# 436663                      312.6                      233.0      1
# 436664                      241.4                       46.0      1
# 436665                      447.2                      462.5      6
# 436666                      675.4                      126.0      0
# 436667                     1832.8                      730.5      2
# 436668                      135.6                      342.5      1
# 436669                      188.0                       72.0      1
# 436670                        8.6                       35.0      1
#
# [436671 rows x 3 columns]
