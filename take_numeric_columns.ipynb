# %%
import os.path
import numpy as np
import pandas as pd
from time import time

# %%
def save_dataframe(df, out_filename):
   # write to csv and no index
    t0 = time()
    df.to_csv(out_filename + ".csv", index=False, encoding='utf-8')
#     df.to_csv(out_filename + ".csv", encoding='utf-8')
    print("time for output csv file: %.2f" % (time()-t0))

# %%
# set configure
# path = "./CDR_MONTHLY_AGGR/"
path = "D:/NEW_DATA_FULL_2017_6_30/"
# path = "C:/Users/VIPLAB/Downloads/Spark_data/"
# path = "./"
filename = "MDS_April_All_SINGLE_SIM_COMPLETED"

# path = "./"
# filename = "dm_subscr_mtc_mly_COMPLETED_revise"
# relative_filename = path + filename + ".csv"
relative_filename = path + filename + ".txt"

# %%
# read csv file and print cost time
t0 = time()
# df = pd.read_csv(relative_filename, usecols = wants_cols, error_bad_lines=False, nrows = 100000)
# df = pd.read_csv(relative_filename, error_bad_lines=False, nrows = 10)
# df = pd.read_csv(relative_filename, error_bad_lines=False, sep = '\t', nrows = 100000)
df = pd.read_csv(relative_filename, error_bad_lines=False, sep = '\t')
print("time for read csv: %.2f" % (time()-t0))
# Out:
# C:\Users\VIPLAB\AppData\Local\conda\conda\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (24,28,76,97,259,260,261,264,267,270,273,276) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# time for read csv: 102.16

# %%
len(df)
# Out:
# 2596797

# %%
df.head()
# Out:
#   DATA_MONTH  MINING_DW_SUBSCR_NO  CURR_SUBSCR_ID DATA_MONTH_RPT_TEMP1  \
# 0   2017/4/1           8134330931       327624391             2017/4/1
# 1   2017/4/1           2118544651       340264445             2017/4/1
# 2   2017/4/1          10000337216       341414412             2017/4/1
# 3   2017/4/1           3133428916       326979481             2017/4/1
# 4   2017/4/1           3119268553       328969946             2017/4/1
#
#   DATA_MONTH_RPT_TEMP2 DATA_MONTH_RPT  DW_PARTY_ID RENEW_IND GA_IND ACTV_TYPE  \
# 0             2017/4/1       2017/4/1      7508599         N      N   PURE GA
# 1             2017/4/1       2017/4/1      5638034         N      N   PURE GA
# 2             2017/4/1       2017/4/1      6556494         N      N       MNP
# 3             2017/4/1       2017/4/1     14170468         N      N       MNP
# 4             2017/4/1       2017/4/1     10424960         N      N       MNP
#
#      ...      L2M_DEVICE_MODEL L2M_DEVICE_PRICE_TIER L2M_DEVICE_TYPE  \
# 0    ...                     ?                     ?               ?
# 1    ...      5310 XpressMusic                     ?          2G H/S
# 2    ...                     ?                     ?               ?
# 3    ...                     ?                     ?               ?
# 4    ...                     ?                     ?               ?
#
#   HS_CHG_CNT AVG_HS_USE_MONTH AVG_HS_USE_MONTH_EX_CURR ZONE_ACTV_IVR_COUNTRY  \
# 0          1              7.0                        ?                     ?
# 1          3             33.0                       40                     ?
# 2          ?                ?                        ?                   高雄市
# 3          1              6.0                        ?                   新北市
# 4          2             32.0                       24                     ?
#
#   ZONE_ACTV_IVR_REGION       STORE_TYPE SPAUTH_IND
# 0                    ?  Mini-New(Y2013)          N
# 1                    ?                ?          N
# 2                  左營區            Store          N
# 3                  瑞芳區            Store          N
# 4                    ?                ?          N
#
# [5 rows x 305 columns]

# %%
len(df.columns)
# Out:
# 305

# %%
# https://stackoverflow.com/questions/25039626/find-numeric-columns-in-pandas-python

# %%
# 將是數值欄位的col和value都秀出來
# df._get_numeric_data()

# %%
#秀出???
# df.select_dtypes(include=[np.number])

# %%
# 秀出數值的欄位名稱 columns name
list(df.select_dtypes(include=[np.number]).columns.values)
# Out:
# ['MINING_DW_SUBSCR_NO',
#  'CURR_SUBSCR_ID',
#  'DW_PARTY_ID',
#  'P6M_AVG_NET_INV_AMT',
#  'TENURE_SCV',
#  'DORMANT_MONTH_CNT_MKT',
#  'PTY_EVER_PO_CNT',
#  'PTY_EVER_PP_CNT',
#  'MULTI_SIM_EXCLUDE_WBB',
#  'MULTI_SIM_INCLUDE_WBB',
#  'ANOTHER_ACTIVE_VD',
#  'ANOTHER_ACTIVE_D',
#  'PTY_CBU_EBU_PO_CNT',
#  'PTY_CBU_PO_CNT',
#  'PTY_CBU_PO_V_CNT',
#  'PTY_CBU_PO_VD_CNT',
#  'PTY_CBU_PO_D_CNT',
#  'PTY_EBU_PO_CNT',
#  'PTY_PO_ALL_CNT',
#  'MDS_CURR_RENEW_CNT',
#  'L6M_AVG_NET_INV_AMT',
#  'NET_INV_AMT',
#  'L1M_NET_INV_AMT',
#  'L2M_NET_INV_AMT',
#  'L3M_NET_INV_AMT',
#  'GPRS_AMT',
#  'L1M_GPRS_AMT',
#  'L2M_GPRS_AMT',
#  'L3M_GPRS_AMT',
#  'AGENCY_AMT',
#  'SMS_INV_AMT',
#  'L3M_AVG_NET_INV_AMT',
#  'L6M_AVG_GPRS_AMT',
#  'L3M_AVG_SMS_INV_AMT',
#  'BOOSTER_AMT',
#  'MT_STM_AMT',
#  'VOICE_RC_AMT',
#  'DATA_RC_AMT',
#  'ONNET_AMT',
#  'OFFNETM_AMT',
#  'PSTN_AMT',
#  'INT_ROAM_AMT',
#  'IDD_AMT',
#  'VAS_AMT',
#  'NRC_AMT',
#  'DATA_INV_AMT',
#  'VOICE_INV_AMT',
#  'MO_TTL_DURATION',
#  'MO_ONNET_DUR',
#  'MO_OFFNET_DUR',
#  'PSTN_DUR',
#  'MO_TTL_COUNT',
#  'MO_ONNET_CNT',
#  'MO_OFFNET_CNT',
#  'PSTN_CNT',
#  'MT_TTL_DURATION',
#  'MT_ONNET_DUR',
#  'MT_OFFNET_DUR',
#  'MT_PSTN_DUR',
#  'MT_TTL_COUNT',
#  'MT_ONNET_CNT',
#  'MT_OFFNET_CNT',
#  'MT_PSTN_CNT',
#  'L3M_AVG_VAS_MB',
#  'L6M_AVG_VAS_MB',
#  'P2P_SMS_MO_CNT',
#  'W2P_SMS_MO_CNT',
#  'OTH_SMS_MO_CNT',
#  'SMS_MO_FET_CNT',
#  'P2P_SMS_MO_ONNET_CNT',
#  'W2P_SMS_MO_ONNET_CNT',
#  'SMS_MO_OFFNET_CNT',
#  'P2P_SMS_MO_OFFNET_CNT',
#  'W2P_SMS_MO_OFFNET_CNT',
#  'SMS_MO_INT_CNT',
#  'P2P_SMS_MO_INT_CNT',
#  'W2P_SMS_MO_INT_CNT',
#  'SMS2P_SMS_MO_CNT',
#  'SMS2AP_SMS_MO_CNT',
#  'DATA_USAGE_MB',
#  'L1M_DATA_USAGE_MB',
#  'L2M_DATA_USAGE_MB',
#  'L3M_DATA_USAGE_MB',
#  'MOC_FET_DUR',
#  'MOC_TWM_DUR',
#  'MOC_CHM_DUR',
#  'MOC_OTH_DUR',
#  'MOC_PSTN_DUR',
#  'MOST_MO_DUR',
#  'MTC_FET_DUR',
#  'MTC_TWM_DUR',
#  'MTC_CHM_DUR',
#  'MTC_PSTN_DUR',
#  'MOST_MT_DUR',
#  'VOICE_MONTHLY_FEE',
#  'DATA_MONTHLY_FEE',
#  'TOTAL_MONTHLY_FEE',
#  'L1M_VOICE_MONTHLY_FEE',
#  'L1M_DATA_MONTHLY_FEE',
#  'DATA_RATING_USAGE_MB']

# %%
len(list(df.select_dtypes(include=[np.number]).columns.values))
# Out:
# 100

# %%
numeric_cols = list(df.select_dtypes(include=[np.number]).columns.values)
numeric_cols.remove('CURR_SUBSCR_ID')
numeric_cols.remove('DW_PARTY_ID')
len(numeric_cols)
# Out:
# 98

# %%
numeric_cols
# Out:
# ['MINING_DW_SUBSCR_NO',
#  'P6M_AVG_NET_INV_AMT',
#  'TENURE_SCV',
#  'DORMANT_MONTH_CNT_MKT',
#  'PTY_EVER_PO_CNT',
#  'PTY_EVER_PP_CNT',
#  'MULTI_SIM_EXCLUDE_WBB',
#  'MULTI_SIM_INCLUDE_WBB',
#  'ANOTHER_ACTIVE_VD',
#  'ANOTHER_ACTIVE_D',
#  'PTY_CBU_EBU_PO_CNT',
#  'PTY_CBU_PO_CNT',
#  'PTY_CBU_PO_V_CNT',
#  'PTY_CBU_PO_VD_CNT',
#  'PTY_CBU_PO_D_CNT',
#  'PTY_EBU_PO_CNT',
#  'PTY_PO_ALL_CNT',
#  'MDS_CURR_RENEW_CNT',
#  'L6M_AVG_NET_INV_AMT',
#  'NET_INV_AMT',
#  'L1M_NET_INV_AMT',
#  'L2M_NET_INV_AMT',
#  'L3M_NET_INV_AMT',
#  'GPRS_AMT',
#  'L1M_GPRS_AMT',
#  'L2M_GPRS_AMT',
#  'L3M_GPRS_AMT',
#  'AGENCY_AMT',
#  'SMS_INV_AMT',
#  'L3M_AVG_NET_INV_AMT',
#  'L6M_AVG_GPRS_AMT',
#  'L3M_AVG_SMS_INV_AMT',
#  'BOOSTER_AMT',
#  'MT_STM_AMT',
#  'VOICE_RC_AMT',
#  'DATA_RC_AMT',
#  'ONNET_AMT',
#  'OFFNETM_AMT',
#  'PSTN_AMT',
#  'INT_ROAM_AMT',
#  'IDD_AMT',
#  'VAS_AMT',
#  'NRC_AMT',
#  'DATA_INV_AMT',
#  'VOICE_INV_AMT',
#  'MO_TTL_DURATION',
#  'MO_ONNET_DUR',
#  'MO_OFFNET_DUR',
#  'PSTN_DUR',
#  'MO_TTL_COUNT',
#  'MO_ONNET_CNT',
#  'MO_OFFNET_CNT',
#  'PSTN_CNT',
#  'MT_TTL_DURATION',
#  'MT_ONNET_DUR',
#  'MT_OFFNET_DUR',
#  'MT_PSTN_DUR',
#  'MT_TTL_COUNT',
#  'MT_ONNET_CNT',
#  'MT_OFFNET_CNT',
#  'MT_PSTN_CNT',
#  'L3M_AVG_VAS_MB',
#  'L6M_AVG_VAS_MB',
#  'P2P_SMS_MO_CNT',
#  'W2P_SMS_MO_CNT',
#  'OTH_SMS_MO_CNT',
#  'SMS_MO_FET_CNT',
#  'P2P_SMS_MO_ONNET_CNT',
#  'W2P_SMS_MO_ONNET_CNT',
#  'SMS_MO_OFFNET_CNT',
#  'P2P_SMS_MO_OFFNET_CNT',
#  'W2P_SMS_MO_OFFNET_CNT',
#  'SMS_MO_INT_CNT',
#  'P2P_SMS_MO_INT_CNT',
#  'W2P_SMS_MO_INT_CNT',
#  'SMS2P_SMS_MO_CNT',
#  'SMS2AP_SMS_MO_CNT',
#  'DATA_USAGE_MB',
#  'L1M_DATA_USAGE_MB',
#  'L2M_DATA_USAGE_MB',
#  'L3M_DATA_USAGE_MB',
#  'MOC_FET_DUR',
#  'MOC_TWM_DUR',
#  'MOC_CHM_DUR',
#  'MOC_OTH_DUR',
#  'MOC_PSTN_DUR',
#  'MOST_MO_DUR',
#  'MTC_FET_DUR',
#  'MTC_TWM_DUR',
#  'MTC_CHM_DUR',
#  'MTC_PSTN_DUR',
#  'MOST_MT_DUR',
#  'VOICE_MONTHLY_FEE',
#  'DATA_MONTHLY_FEE',
#  'TOTAL_MONTHLY_FEE',
#  'L1M_VOICE_MONTHLY_FEE',
#  'L1M_DATA_MONTHLY_FEE',
#  'DATA_RATING_USAGE_MB']

# %% [markdown]
# # Combine Marketing data and Groups

# %%
numeric_df = df[numeric_cols]

# %%
# user_df.sort_values(["AGE"], inplace = True)
numeric_df = numeric_df.set_index("MINING_DW_SUBSCR_NO")
numeric_df.sort_index(inplace = True)
numeric_df["Groups"] = np.nan

# %%
numeric_df.head()
# Out:
#                      P6M_AVG_NET_INV_AMT  TENURE_SCV  DORMANT_MONTH_CNT_MKT  \
# MINING_DW_SUBSCR_NO
# 1179                             1088.04       188.2                      0
# 1181                              515.67       188.2                      0
# 11121                            1718.87       188.2                      0
# 11145                            1300.15       188.2                      0
# 11149                             656.37       188.2                      0
#
#                      PTY_EVER_PO_CNT  PTY_EVER_PP_CNT  MULTI_SIM_EXCLUDE_WBB  \
# MINING_DW_SUBSCR_NO
# 1179                               1                1                      0
# 1181                               1                1                      0
# 11121                              2                2                      0
# 11145                              2                1                      0
# 11149                              3                0                      0
#
#                      MULTI_SIM_INCLUDE_WBB  ANOTHER_ACTIVE_VD  \
# MINING_DW_SUBSCR_NO
# 1179                                     1                  0
# 1181                                     2                  0
# 11121                                    1                  0
# 11145                                    1                  0
# 11149                                    1                  0
#
#                      ANOTHER_ACTIVE_D  PTY_CBU_EBU_PO_CNT   ...    \
# MINING_DW_SUBSCR_NO                                         ...
# 1179                                0                   1   ...
# 1181                                0                   1   ...
# 11121                               0                   1   ...
# 11145                               0                   1   ...
# 11149                               0                   1   ...
#
#                      MTC_CHM_DUR  MTC_PSTN_DUR  MOST_MT_DUR  \
# MINING_DW_SUBSCR_NO
# 1179                        1358           238         9720
# 1181                         357            44          608
# 11121                        587           509          587
# 11145                         52             0         1778
# 11149                       2284           110         2284
#
#                      VOICE_MONTHLY_FEE  DATA_MONTHLY_FEE  TOTAL_MONTHLY_FEE  \
# MINING_DW_SUBSCR_NO
# 1179                               598               775               1373
# 1181                                 0               599                599
# 11121                                0              1399               1399
# 11145                                0               999                999
# 11149                                0               599                599
#
#                      L1M_VOICE_MONTHLY_FEE  L1M_DATA_MONTHLY_FEE  \
# MINING_DW_SUBSCR_NO
# 1179                                   598                   775
# 1181                                     0                   599
# 11121                                    0                  1399
# 11145                                    0                   999
# 11149                                    0                   599
#
#                      DATA_RATING_USAGE_MB  Groups
# MINING_DW_SUBSCR_NO
# 1179                                 2993     NaN
# 1181                                 2427     NaN
# 11121                                2192     NaN
# 11145                                2152     NaN
# 11149                                1653     NaN
#
# [5 rows x 98 columns]

# %% [markdown]
# # LOAD MINING USER's Group

# %%
path = "./"
relative_filename = path + "DNA_KMEANS_RESULT_ID_NEW" + ".csv"
wants_cols = ["MINING_DW_SUBSCR_NO", "Groups"]
group_df =  pd.read_csv(relative_filename, error_bad_lines=False, usecols = wants_cols)

# %%
group_df = group_df.set_index("MINING_DW_SUBSCR_NO")
group_df.sort_index(inplace = True)

# %%
marketing_group = numeric_df[['Groups']]
marketing_group.update(group_df)
numeric_df[['Groups']] = marketing_group
# Out:
# C:\Users\VIPLAB\AppData\Local\conda\conda\envs\py36\lib\site-packages\pandas\core\frame.py:3863: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   raise_on_error=True)

# %%
numeric_df.groupby('Groups').count()
# Out:
#         P6M_AVG_NET_INV_AMT  TENURE_SCV  DORMANT_MONTH_CNT_MKT  \
# Groups
# 1                    407597      407597                 407597
# 2                    184644      184644                 184644
# 3                    105809      105809                 105809
# 4                    116958      116958                 116958
# 5                    110474      110474                 110474
# 6                    146047      146047                 146047
# 7                    164149      164149                 164149
# 8                    490166      490166                 490166
# None                 531990      531990                 531990
# seldom               338963      338963                 338963
#
#         PTY_EVER_PO_CNT  PTY_EVER_PP_CNT  MULTI_SIM_EXCLUDE_WBB  \
# Groups
# 1                407597           407597                 407597
# 2                184644           184644                 184644
# 3                105809           105809                 105809
# 4                116958           116958                 116958
# 5                110474           110474                 110474
# 6                146047           146047                 146047
# 7                164149           164149                 164149
# 8                490166           490166                 490166
# None             531990           531990                 531990
# seldom           338963           338963                 338963
#
#         MULTI_SIM_INCLUDE_WBB  ANOTHER_ACTIVE_VD  ANOTHER_ACTIVE_D  \
# Groups
# 1                      407597             407597            407597
# 2                      184644             184644            184644
# 3                      105809             105809            105809
# 4                      116958             116958            116958
# 5                      110474             110474            110474
# 6                      146047             146047            146047
# 7                      164149             164149            164149
# 8                      490166             490166            490166
# None                   531990             531990            531990
# seldom                 338963             338963            338963
#
#         PTY_CBU_EBU_PO_CNT          ...           MTC_TWM_DUR  MTC_CHM_DUR  \
# Groups                              ...
# 1                   407597          ...                407597       407597
# 2                   184644          ...                184644       184644
# 3                   105809          ...                105809       105809
# 4                   116958          ...                116958       116958
# 5                   110474          ...                110474       110474
# 6                   146047          ...                146047       146047
# 7                   164149          ...                164149       164149
# 8                   490166          ...                490166       490166
# None                531990          ...                531990       531990
# seldom              338963          ...                338963       338963
#
#         MTC_PSTN_DUR  MOST_MT_DUR  VOICE_MONTHLY_FEE  DATA_MONTHLY_FEE  \
# Groups
# 1             407597       407597             407597            407597
# 2             184644       184644             184644            184644
# 3             105809       105809             105809            105809
# 4             116958       116958             116958            116958
# 5             110474       110474             110474            110474
# 6             146047       146047             146047            146047
# 7             164149       164149             164149            164149
# 8             490166       490166             490166            490166
# None          531990       531990             531990            531990
# seldom        338963       338963             338963            338963
#
#         TOTAL_MONTHLY_FEE  L1M_VOICE_MONTHLY_FEE  L1M_DATA_MONTHLY_FEE  \
# Groups
# 1                  407597                 407597                407597
# 2                  184644                 184644                184644
# 3                  105809                 105809                105809
# 4                  116958                 116958                116958
# 5                  110474                 110474                110474
# 6                  146047                 146047                146047
# 7                  164149                 164149                164149
# 8                  490166                 490166                490166
# None               531990                 531990                531990
# seldom             338963                 338963                338963
#
#         DATA_RATING_USAGE_MB
# Groups
# 1                     407597
# 2                     184644
# 3                     105809
# 4                     116958
# 5                     110474
# 6                     146047
# 7                     164149
# 8                     490166
# None                  531990
# seldom                338963
#
# [10 rows x 97 columns]

# %% [markdown]
# # save numeric data

# %%
path = "./marketing_analyze/"
out_filename = path + "april_marketing_anylze_numeric"
save_dataframe(numeric_df, out_filename)
