# %%
import os.path
import numpy as np
import pandas as pd
from time import time
from glob import glob
from mailerWithUtf8 import mail

# %%
def save_dataframe(df, out_filename):
   # write to csv and no index
    t0 = time()
    df.to_csv(out_filename + ".csv", index=False, encoding='utf-8')
    print("time for output csv file: %.2f" % (time()-t0))

# %%
def read_csv(filename):
    # read revise csv file and print cost time
    t0 = time()
    df = pd.read_csv(filename, error_bad_lines=False)
    print("time for read csv: %.2f" % (time()-t0))
    return df

# %%
path ='./clf_random_forest_model_kFold/' # use your path
# all_files = glob(path + "*.feather")
# all_files = glob(path + "*.csv")

# %%
all_dirs = glob(path)

# %%
all_dirs
# Out:
# ['./clf_random_forest_model_kFold/']

# %%
df = pd.DataFrame()
for root, dirnames, filenames in os.walk(path):
    if dirnames:
        print(dirnames)
        for _dir in dirnames:
            all_csvs = glob(path + _dir + "/" + "*.csv")
            for csv_file in all_csvs:
                print(csv_file)
                if "descent" in csv_file:
                    print(csv_file)
                    t_df = read_csv(csv_file)
                    df[str(_dir)] = t_df["COLUMN"]
#                     df =df.append(t_df)
                    del t_df
# Out:
# ['Adult', 'all', 'Entertainment', 'Game', 'Infrequent_User', 'InstantMessage-High', 'InstantMessage-SuperHigh', 'Lifestyle', 'No_significant_preference', 'No_significant_preference(instant_message)', 'Portal', 'Social-media']
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult__accuracy.csv
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all_confusion_matrix.csv
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all_feature_important_descent.csv
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all__accuracy.csv
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment__accuracy.csv
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game__accuracy.csv
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User__accuracy.csv
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High_confusion_matrix.csv
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High_feature_important_descent.csv
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High__accuracy.csv
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh_confusion_matrix.csv
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh_feature_important_descent.csv
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh__accuracy.csv
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle__accuracy.csv
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference_confusion_matrix.csv
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference_feature_important_descent.csv
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference__accuracy.csv
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)_confusion_matrix.csv
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)_feature_important_descent.csv
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)__accuracy.csv
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal__accuracy.csv
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media_feature_important_descent.csv
# time for read csv: 0.00
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media__accuracy.csv

# %%
df.head()
# Out:
#                       Adult                    all     Entertainment  \
# 0     P3M_AVG_DATA_USAGE_MB  P3M_AVG_DATA_USAGE_MB       MOC_TWM_CNT
# 1               GENDER_CODE          IMEI_MFG_NAME  MOST_MO_OPERATOR
# 2  CURR_DATA_BILL_PLAN_NAME          IMEI_MKT_NAME       MTC_TWM_CNT
# 3          DATA_MONTHLY_FEE    L3M_AVG_NET_INV_AMT  MOST_MT_OPERATOR
# 4     PROM_FLAT_RATE_4G_IND                    AGE       MTC_APT_CNT
#
#                   Game           Infrequent_User  InstantMessage-High  \
# 0          MTC_APT_CNT     P3M_AVG_DATA_USAGE_MB          MOC_TWM_CNT
# 1          MOC_TWM_CNT          DATA_MONTHLY_FEE          MTC_APT_CNT
# 2          MTC_TSC_CNT     PROM_FLAT_RATE_4G_IND  L3M_AVG_MO_PSTN_CNT
# 3  L3M_AVG_MO_PSTN_CNT          FLAT_RATE_4G_IND          MTC_TWM_CNT
# 4          MTC_TWM_CNT  CURR_DATA_BILL_PLAN_NAME        IMEI_MFG_NAME
#
#   InstantMessage-SuperHigh                 Lifestyle  \
# 0              MOC_TWM_CNT     P3M_AVG_DATA_USAGE_MB
# 1              MTC_APT_CNT  CURR_DATA_BILL_PLAN_NAME
# 2              MTC_TWM_CNT               MOC_TWM_CNT
# 3              MOC_CHM_CNT     PROM_FLAT_RATE_4G_IND
# 4              MTC_TSC_CNT          DATA_MONTHLY_FEE
#
#   No_significant_preference No_significant_preference(instant_message)  \
# 0             IMEI_MFG_NAME                        L3M_AVG_MO_PSTN_CNT
# 1             IMEI_MKT_NAME                                MOC_TWM_CNT
# 2               MTC_APT_CNT                                MOC_CHM_CNT
# 3               MOC_TWM_CNT                                MTC_APT_CNT
# 4  PROM_CURR_PROMOTION_TYPE                      P3M_AVG_DATA_USAGE_MB
#
#                 Portal Social-media
# 0        IMEI_MFG_NAME  MOC_TWM_CNT
# 1        IMEI_MKT_NAME  MOC_CHM_CNT
# 2  L3M_AVG_MT_PSTN_CNT  MTC_APT_CNT
# 3  MDS_CURR_RENEW_TYPE  MTC_TSC_CNT
# 4          MOC_TWM_CNT  MTC_TWM_CNT

# %%
df.to_csv(path + "random_forests_groups_rank.csv", encoding='utf-8')

# %%
df = pd.DataFrame()
for root, dirnames, filenames in os.walk(path):
    if dirnames:
        print(dirnames)
        for _dir in dirnames:
            all_csvs = glob(path + _dir + "/" + "*.csv")
            for csv_file in all_csvs:
                print(csv_file)
                if "one_row" in csv_file:
                    print(csv_file)
                    t_df = read_csv(csv_file)
                    print(len(df.columns))
                    if(len(df.columns) == 0):
                        print("in 0")
                        df = pd.DataFrame(columns = t_df.columns)
                        print("df.colums")
                        print(df.columns)

                    t_df.head()
                    df =df.append(t_df)
                    del t_df
# Out:
# ['Adult', 'all', 'Entertainment', 'Game', 'Infrequent_User', 'InstantMessage-High', 'InstantMessage-SuperHigh', 'Lifestyle', 'No_significant_preference', 'No_significant_preference(instant_message)', 'Portal', 'Social-media']
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult_feature_important_one_row.csv
# time for read csv: 0.00
# 0
# in 0
# df.colums
# Index(['ACTV_TYPE', 'AGE', 'APPLY_CURR_EBILL_SBILL_FLAG', 'AUTOPAY_IND',
#        'AVG_HS_USE_MONTH_EX_CURR', 'BILL_ZIP_CODE', 'BOOSTER_AMT',
#        'CHANNEL_CHURN_INDEX', 'CHURN_CLM_IND', 'CURR_DATA_BILL_PLAN_NAME',
#        ...
#        'SERVICE_STATUS_OMUSIC_FLAG', 'SERVICE_STATUS_READING_FLAG',
#        'SRV_TYPE_DESC', 'TENURE_SCV', 'TOTAL_MONTHLY_FEE', 'VIP_GRADE',
#        'VIP_REDEEM_IND', 'VIP_TENURE', 'VOICE_MONTHLY_FEE',
#        'ZONE_ACTIVATION_IVR'],
#       dtype='object', length=105)
# ./clf_random_forest_model_kFold/Adult\RANDOM_FOREST_Adult__accuracy.csv
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all_confusion_matrix.csv
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all_feature_important_descent.csv
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/all\RANDOM_FOREST_all__accuracy.csv
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/Entertainment\RANDOM_FOREST_Entertainment__accuracy.csv
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/Game\RANDOM_FOREST_Game__accuracy.csv
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/Infrequent_User\RANDOM_FOREST_Infrequent_User__accuracy.csv
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High_confusion_matrix.csv
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High_feature_important_descent.csv
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/InstantMessage-High\RANDOM_FOREST_InstantMessage-High__accuracy.csv
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh_confusion_matrix.csv
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh_feature_important_descent.csv
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/InstantMessage-SuperHigh\RANDOM_FOREST_InstantMessage-SuperHigh__accuracy.csv
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/Lifestyle\RANDOM_FOREST_Lifestyle__accuracy.csv
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference_confusion_matrix.csv
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference_feature_important_descent.csv
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/No_significant_preference\RANDOM_FOREST_No_significant_preference__accuracy.csv
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)_confusion_matrix.csv
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)_feature_important_descent.csv
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/No_significant_preference(instant_message)\RANDOM_FOREST_No_significant_preference(instant_message)__accuracy.csv
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal_feature_important_one_row.csv
# time for read csv: 0.01
# 105
# ./clf_random_forest_model_kFold/Portal\RANDOM_FOREST_Portal__accuracy.csv
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media_confusion_matrix.csv
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media_feature_important_descent.csv
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media_feature_important_one_row.csv
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media_feature_important_one_row.csv
# time for read csv: 0.00
# 105
# ./clf_random_forest_model_kFold/Social-media\RANDOM_FOREST_Social-media__accuracy.csv

# %%
df = df.set_index("Groups")

# %%
df.to_csv(path + "random_forests_groups_importances.csv", encoding='utf-8')

# %%
df.head()
# Out:
#                  ACTV_TYPE       AGE  APPLY_CURR_EBILL_SBILL_FLAG  \
# Groups
# Adult             0.007501  0.008721                     0.000622
# all               0.003616  0.032523                     0.002198
# Entertainment     0.007829  0.005447                     0.000253
# Game              0.007162  0.004422                     0.000400
# Infrequent_User   0.003616  0.025813                     0.000419
#
#                  AUTOPAY_IND  AVG_HS_USE_MONTH_EX_CURR  BILL_ZIP_CODE  \
# Groups
# Adult               0.000364                  0.003236       0.001073
# all                 0.000585                  0.008174       0.012688
# Entertainment       0.000067                  0.003127       0.000844
# Game                0.000104                  0.003296       0.001112
# Infrequent_User     0.000094                  0.001590       0.000886
#
#                  BOOSTER_AMT  CHANNEL_CHURN_INDEX  CHURN_CLM_IND  \
# Groups
# Adult               0.000068             0.000989       0.005506
# all                 0.000123             0.000347       0.002599
# Entertainment       0.000083             0.000446       0.003168
# Game                0.000047             0.000937       0.005221
# Infrequent_User     0.000211             0.000839       0.005462
#
#                  CURR_DATA_BILL_PLAN_NAME         ...           \
# Groups                                            ...
# Adult                            0.041303         ...
# all                              0.027649         ...
# Entertainment                    0.031035         ...
# Game                             0.026065         ...
# Infrequent_User                  0.067804         ...
#
#                  SERVICE_STATUS_OMUSIC_FLAG  SERVICE_STATUS_READING_FLAG  \
# Groups
# Adult                                   0.0                 0.000000e+00
# all                                     0.0                 0.000000e+00
# Entertainment                           0.0                 0.000000e+00
# Game                                    0.0                 0.000000e+00
# Infrequent_User                         0.0                 1.794151e-08
#
#                  SRV_TYPE_DESC  TENURE_SCV  TOTAL_MONTHLY_FEE  VIP_GRADE  \
# Groups
# Adult                 0.020456    0.008976           0.026835   0.001844
# all                   0.008199    0.017756           0.019199   0.000635
# Entertainment         0.018706    0.009585           0.022853   0.000783
# Game                  0.011396    0.010319           0.018846   0.002227
# Infrequent_User       0.027567    0.006945           0.055220   0.000183
#
#                  VIP_REDEEM_IND  VIP_TENURE  VOICE_MONTHLY_FEE  \
# Groups
# Adult                  0.000213    0.001608           0.012520
# all                    0.000047    0.000786           0.004947
# Entertainment          0.000021    0.001090           0.011454
# Game                   0.000111    0.003378           0.009438
# Infrequent_User        0.000007    0.000259           0.017137
#
#                  ZONE_ACTIVATION_IVR
# Groups
# Adult                       0.002078
# all                         0.003458
# Entertainment               0.001349
# Game                        0.001526
# Infrequent_User             0.001627
#
# [5 rows x 104 columns]

# %%
importance_df = df.transpose()

# %%
importance_df.head()
# Out:
# Groups                          Adult       all  Entertainment      Game  \
# ACTV_TYPE                    0.007501  0.003616       0.007829  0.007162
# AGE                          0.008721  0.032523       0.005447  0.004422
# APPLY_CURR_EBILL_SBILL_FLAG  0.000622  0.002198       0.000253  0.000400
# AUTOPAY_IND                  0.000364  0.000585       0.000067  0.000104
# AVG_HS_USE_MONTH_EX_CURR     0.003236  0.008174       0.003127  0.003296
#
# Groups                       Infrequent_User  InstantMessage-High  \
# ACTV_TYPE                           0.003616             0.002676
# AGE                                 0.025813             0.008799
# APPLY_CURR_EBILL_SBILL_FLAG         0.000419             0.000826
# AUTOPAY_IND                         0.000094             0.000308
# AVG_HS_USE_MONTH_EX_CURR            0.001590             0.003110
#
# Groups                       InstantMessage-SuperHigh  Lifestyle  \
# ACTV_TYPE                                    0.002632   0.013216
# AGE                                          0.006552   0.025658
# APPLY_CURR_EBILL_SBILL_FLAG                  0.000595   0.000374
# AUTOPAY_IND                                  0.000353   0.000177
# AVG_HS_USE_MONTH_EX_CURR                     0.002856   0.005239
#
# Groups                       No_significant_preference  \
# ACTV_TYPE                                     0.003898
# AGE                                           0.011511
# APPLY_CURR_EBILL_SBILL_FLAG                   0.000597
# AUTOPAY_IND                                   0.000167
# AVG_HS_USE_MONTH_EX_CURR                      0.003033
#
# Groups                       No_significant_preference(instant_message)  \
# ACTV_TYPE                                                      0.007949
# AGE                                                            0.015268
# APPLY_CURR_EBILL_SBILL_FLAG                                    0.000520
# AUTOPAY_IND                                                    0.000210
# AVG_HS_USE_MONTH_EX_CURR                                       0.004169
#
# Groups                         Portal  Social-media
# ACTV_TYPE                    0.020009      0.005056
# AGE                          0.016914      0.012808
# APPLY_CURR_EBILL_SBILL_FLAG  0.000565      0.000880
# AUTOPAY_IND                  0.000190      0.000271
# AVG_HS_USE_MONTH_EX_CURR     0.004135      0.002571

# %%
importance_df = importance_df.sort_values('all' , ascending= False)

# %%
importance_df = importance_df.drop("all", axis = 1)

# %%
importance_df = importance_df.round(6)

# %%
importance_df.to_csv(path + "importance_by_all_df.csv", encoding='utf-8')

# %%
importance_df
# Out:
# Groups                           Adult  Entertainment      Game  \
# P3M_AVG_DATA_USAGE_MB         0.082799       0.025589  0.017323
# IMEI_MFG_NAME                 0.024482       0.014573  0.002449
# IMEI_MKT_NAME                 0.025425       0.017371  0.003317
# L3M_AVG_NET_INV_AMT           0.017234       0.016565  0.015170
# AGE                           0.008721       0.005447  0.004422
# CURR_DATA_BILL_PLAN_NAME      0.041303       0.031035  0.026065
# DATA_MONTHLY_FEE              0.040578       0.030855  0.023403
# FLAT_RATE_4G_IND              0.031837       0.032918  0.022077
# PROM_FLAT_RATE_4G_IND         0.039932       0.033399  0.025870
# PROM_CURR_PROMOTION_TYPE      0.022557       0.024047  0.016094
# TOTAL_MONTHLY_FEE             0.026835       0.022853  0.018846
# PROM_CURR_EXP_MONTH_CNT       0.013632       0.013050  0.011580
# TENURE_SCV                    0.008976       0.009585  0.010319
# L3M_AVG_MO_PSTN_CNT           0.022467       0.030099  0.040928
# L3M_AVG_MT_PSTN_CNT           0.022620       0.026784  0.029566
# PROM_CURR_PROMOTION_SUB_TYPE  0.017073       0.017579  0.013732
# L3M_AVG_MT_TTL_DUR            0.004371       0.007056  0.005339
# L3M_AVG_MO_PSTN_DUR           0.005008       0.005764  0.007462
# L3M_AVG_MT_PSTN_DUR           0.007266       0.006115  0.006560
# L3M_AVG_MT_OFFNET_DUR         0.003426       0.008245  0.005436
# L3M_AVG_MO_TTL_CNT            0.004289       0.016282  0.010340
# L3M_AVG_MT_TTL_CNT            0.004278       0.010886  0.005879
# L3M_AVG_MO_OFFNET_DUR         0.002992       0.006681  0.005372
# L3M_AVG_MO_OFFNET_CNT         0.008656       0.027429  0.020534
# L3M_AVG_MT_ONNET_CNT          0.007298       0.013625  0.017557
# L3M_AVG_MT_OFFNET_CNT         0.006809       0.017126  0.009937
# L3M_AVG_MO_TTL_DUR            0.002549       0.003630  0.003496
# L3M_AVG_MT_ONNET_DUR          0.002705       0.004605  0.004587
# L3M_AVG_PSTN_AMT              0.006171       0.005649  0.008594
# MOC_TWM_CNT                   0.031194       0.039932  0.054942
# ...                                ...            ...       ...
# HS_LEASE_FEATURE_NAME         0.001366       0.000804  0.001201
# L3M_AVG_IDD_AMT               0.000029       0.000051  0.000036
# VIP_TENURE                    0.001608       0.001090  0.003378
# SELFCARE_IND                  0.000158       0.000051  0.000077
# VIP_GRADE                     0.001844       0.000783  0.002227
# AUTOPAY_IND                   0.000364       0.000067  0.000104
# MSISDN_LAST_NP_OUT_IND        0.000869       0.000521  0.000836
# CHANNEL_CHURN_INDEX           0.000989       0.000446  0.000937
# SERVICE_STATUS_MOVIE_FLAG     0.000107       0.000058  0.000078
# L3M_AVG_GPRS_AMT              0.000123       0.000125  0.000087
# DATA_BOOSTER_EVER_USE_FLAG    0.000113       0.000157  0.000131
# BOOSTER_AMT                   0.000068       0.000083  0.000047
# CWC_CATG7_CNT                 0.000053       0.000066  0.000098
# CWC_CATG1_CNT                 0.000240       0.000162  0.000291
# VIP_REDEEM_IND                0.000213       0.000021  0.000111
# CWC_CATG13_CNT                0.000007       0.000005  0.000008
# CWC_CATG9_CNT                 0.000033       0.000012  0.000010
# CWC_CATG2_CNT                 0.000016       0.000020  0.000015
# CWC_CATG8_CNT                 0.000015       0.000008  0.000017
# CWC_CATG3_CNT                 0.000005       0.000016  0.000016
# CWC_CATG12_CNT                0.000009       0.000013  0.000023
# CWC_CATG5_CNT                 0.000006       0.000008  0.000006
# CWC_CATG10_CNT                0.000002       0.000007  0.000005
# CWC_CATG11_CNT                0.000004       0.000004  0.000005
# CWC_CATG4_CNT                 0.000001       0.000003  0.000002
# GA_IND                        0.000000       0.000000  0.000000
# SERVICE_STATUS_READING_FLAG   0.000000       0.000000  0.000000
# SERVICE_STATUS_OMUSIC_FLAG    0.000000       0.000000  0.000000
# CWC_CATG6_CNT                 0.000001       0.000002  0.000001
# PAY_PENALTY_FLAG              0.000000       0.000000  0.000000
#
# Groups                        Infrequent_User  InstantMessage-High  \
# P3M_AVG_DATA_USAGE_MB                0.175708             0.027795
# IMEI_MFG_NAME                        0.005265             0.039486
# IMEI_MKT_NAME                        0.011064             0.036486
# L3M_AVG_NET_INV_AMT                  0.056235             0.015086
# AGE                                  0.025813             0.008799
# CURR_DATA_BILL_PLAN_NAME             0.067804             0.031384
# DATA_MONTHLY_FEE                     0.083673             0.025433
# FLAT_RATE_4G_IND                     0.070752             0.028846
# PROM_FLAT_RATE_4G_IND                0.073938             0.028609
# PROM_CURR_PROMOTION_TYPE             0.048885             0.022671
# TOTAL_MONTHLY_FEE                    0.055220             0.018589
# PROM_CURR_EXP_MONTH_CNT              0.014822             0.012785
# TENURE_SCV                           0.006945             0.007951
# L3M_AVG_MO_PSTN_CNT                  0.019338             0.041667
# L3M_AVG_MT_PSTN_CNT                  0.010298             0.032218
# PROM_CURR_PROMOTION_SUB_TYPE         0.024015             0.014746
# L3M_AVG_MT_TTL_DUR                   0.003781             0.004082
# L3M_AVG_MO_PSTN_DUR                  0.004125             0.010827
# L3M_AVG_MT_PSTN_DUR                  0.003231             0.008071
# L3M_AVG_MT_OFFNET_DUR                0.001953             0.006660
# L3M_AVG_MO_TTL_CNT                   0.008862             0.007238
# L3M_AVG_MT_TTL_CNT                   0.005445             0.006218
# L3M_AVG_MO_OFFNET_DUR                0.002332             0.005916
# L3M_AVG_MO_OFFNET_CNT                0.005459             0.012453
# L3M_AVG_MT_ONNET_CNT                 0.007336             0.020061
# L3M_AVG_MT_OFFNET_CNT                0.005450             0.012165
# L3M_AVG_MO_TTL_DUR                   0.002544             0.004272
# L3M_AVG_MT_ONNET_DUR                 0.001485             0.005008
# L3M_AVG_PSTN_AMT                     0.008333             0.008764
# MOC_TWM_CNT                          0.005904             0.059776
# ...                                       ...                  ...
# HS_LEASE_FEATURE_NAME                0.000608             0.001529
# L3M_AVG_IDD_AMT                      0.000038             0.000392
# VIP_TENURE                           0.000259             0.001417
# SELFCARE_IND                         0.000601             0.000387
# VIP_GRADE                            0.000183             0.001505
# AUTOPAY_IND                          0.000094             0.000308
# MSISDN_LAST_NP_OUT_IND               0.000244             0.000365
# CHANNEL_CHURN_INDEX                  0.000839             0.000313
# SERVICE_STATUS_MOVIE_FLAG            0.000066             0.000108
# L3M_AVG_GPRS_AMT                     0.000447             0.000140
# DATA_BOOSTER_EVER_USE_FLAG           0.000508             0.000113
# BOOSTER_AMT                          0.000211             0.000067
# CWC_CATG7_CNT                        0.000009             0.000054
# CWC_CATG1_CNT                        0.000024             0.000095
# VIP_REDEEM_IND                       0.000007             0.000080
# CWC_CATG13_CNT                       0.000001             0.000021
# CWC_CATG9_CNT                        0.000037             0.000009
# CWC_CATG2_CNT                        0.000006             0.000015
# CWC_CATG8_CNT                        0.000001             0.000007
# CWC_CATG3_CNT                        0.000003             0.000010
# CWC_CATG12_CNT                       0.000017             0.000008
# CWC_CATG5_CNT                        0.000002             0.000003
# CWC_CATG10_CNT                       0.000001             0.000002
# CWC_CATG11_CNT                       0.000001             0.000003
# CWC_CATG4_CNT                        0.000000             0.000001
# GA_IND                               0.000000             0.000000
# SERVICE_STATUS_READING_FLAG          0.000000             0.000000
# SERVICE_STATUS_OMUSIC_FLAG           0.000000             0.000000
# CWC_CATG6_CNT                        0.000000             0.000000
# PAY_PENALTY_FLAG                     0.000000             0.000000
#
# Groups                        InstantMessage-SuperHigh  Lifestyle  \
# P3M_AVG_DATA_USAGE_MB                         0.033298   0.075943
# IMEI_MFG_NAME                                 0.029012   0.008119
# IMEI_MKT_NAME                                 0.022593   0.010266
# L3M_AVG_NET_INV_AMT                           0.011230   0.017907
# AGE                                           0.006552   0.025658
# CURR_DATA_BILL_PLAN_NAME                      0.020117   0.045796
# DATA_MONTHLY_FEE                              0.016036   0.037960
# FLAT_RATE_4G_IND                              0.017366   0.031588
# PROM_FLAT_RATE_4G_IND                         0.018880   0.039584
# PROM_CURR_PROMOTION_TYPE                      0.014000   0.021659
# TOTAL_MONTHLY_FEE                             0.012087   0.024295
# PROM_CURR_EXP_MONTH_CNT                       0.008654   0.014338
# TENURE_SCV                                    0.006999   0.016695
# L3M_AVG_MO_PSTN_CNT                           0.031136   0.028567
# L3M_AVG_MT_PSTN_CNT                           0.041502   0.021609
# PROM_CURR_PROMOTION_SUB_TYPE                  0.008511   0.016490
# L3M_AVG_MT_TTL_DUR                            0.004019   0.002323
# L3M_AVG_MO_PSTN_DUR                           0.006878   0.006317
# L3M_AVG_MT_PSTN_DUR                           0.012217   0.005436
# L3M_AVG_MT_OFFNET_DUR                         0.005993   0.004857
# L3M_AVG_MO_TTL_CNT                            0.006636   0.006652
# L3M_AVG_MT_TTL_CNT                            0.005518   0.005037
# L3M_AVG_MO_OFFNET_DUR                         0.005925   0.004474
# L3M_AVG_MO_OFFNET_CNT                         0.013590   0.013545
# L3M_AVG_MT_ONNET_CNT                          0.022628   0.015060
# L3M_AVG_MT_OFFNET_CNT                         0.009389   0.008410
# L3M_AVG_MO_TTL_DUR                            0.003719   0.002709
# L3M_AVG_MT_ONNET_DUR                          0.004829   0.003074
# L3M_AVG_PSTN_AMT                              0.005153   0.005767
# MOC_TWM_CNT                                   0.071968   0.040836
# ...                                                ...        ...
# HS_LEASE_FEATURE_NAME                         0.000833   0.002218
# L3M_AVG_IDD_AMT                               0.011758   0.000031
# VIP_TENURE                                    0.001278   0.001713
# SELFCARE_IND                                  0.000190   0.000097
# VIP_GRADE                                     0.002546   0.001782
# AUTOPAY_IND                                   0.000353   0.000177
# MSISDN_LAST_NP_OUT_IND                        0.000334   0.001196
# CHANNEL_CHURN_INDEX                           0.000266   0.000915
# SERVICE_STATUS_MOVIE_FLAG                     0.000089   0.000065
# L3M_AVG_GPRS_AMT                              0.000049   0.000083
# DATA_BOOSTER_EVER_USE_FLAG                    0.000089   0.000117
# BOOSTER_AMT                                   0.000039   0.000093
# CWC_CATG7_CNT                                 0.000044   0.000078
# CWC_CATG1_CNT                                 0.000054   0.000103
# VIP_REDEEM_IND                                0.000163   0.000071
# CWC_CATG13_CNT                                0.000046   0.000006
# CWC_CATG9_CNT                                 0.000009   0.000007
# CWC_CATG2_CNT                                 0.000019   0.000018
# CWC_CATG8_CNT                                 0.000017   0.000012
# CWC_CATG3_CNT                                 0.000010   0.000011
# CWC_CATG12_CNT                                0.000005   0.000009
# CWC_CATG5_CNT                                 0.000001   0.000005
# CWC_CATG10_CNT                                0.000003   0.000004
# CWC_CATG11_CNT                                0.000001   0.000002
# CWC_CATG4_CNT                                 0.000001   0.000002
# GA_IND                                        0.000000   0.000000
# SERVICE_STATUS_READING_FLAG                   0.000000   0.000000
# SERVICE_STATUS_OMUSIC_FLAG                    0.000000   0.000000
# CWC_CATG6_CNT                                 0.000000   0.000001
# PAY_PENALTY_FLAG                              0.000000   0.000000
#
# Groups                        No_significant_preference  \
# P3M_AVG_DATA_USAGE_MB                          0.022709
# IMEI_MFG_NAME                                  0.100540
# IMEI_MKT_NAME                                  0.070618
# L3M_AVG_NET_INV_AMT                            0.017083
# AGE                                            0.011511
# CURR_DATA_BILL_PLAN_NAME                       0.029582
# DATA_MONTHLY_FEE                               0.027388
# FLAT_RATE_4G_IND                               0.024331
# PROM_FLAT_RATE_4G_IND                          0.026635
# PROM_CURR_PROMOTION_TYPE                       0.030760
# TOTAL_MONTHLY_FEE                              0.018866
# PROM_CURR_EXP_MONTH_CNT                        0.011979
# TENURE_SCV                                     0.008989
# L3M_AVG_MO_PSTN_CNT                            0.023447
# L3M_AVG_MT_PSTN_CNT                            0.021452
# PROM_CURR_PROMOTION_SUB_TYPE                   0.016948
# L3M_AVG_MT_TTL_DUR                             0.006850
# L3M_AVG_MO_PSTN_DUR                            0.006194
# L3M_AVG_MT_PSTN_DUR                            0.007081
# L3M_AVG_MT_OFFNET_DUR                          0.007681
# L3M_AVG_MO_TTL_CNT                             0.009172
# L3M_AVG_MT_TTL_CNT                             0.008549
# L3M_AVG_MO_OFFNET_DUR                          0.006391
# L3M_AVG_MO_OFFNET_CNT                          0.015794
# L3M_AVG_MT_ONNET_CNT                           0.009601
# L3M_AVG_MT_OFFNET_CNT                          0.016242
# L3M_AVG_MO_TTL_DUR                             0.004856
# L3M_AVG_MT_ONNET_DUR                           0.005161
# L3M_AVG_PSTN_AMT                               0.006431
# MOC_TWM_CNT                                    0.034256
# ...                                                 ...
# HS_LEASE_FEATURE_NAME                          0.001086
# L3M_AVG_IDD_AMT                                0.000084
# VIP_TENURE                                     0.002065
# SELFCARE_IND                                   0.000270
# VIP_GRADE                                      0.001333
# AUTOPAY_IND                                    0.000167
# MSISDN_LAST_NP_OUT_IND                         0.000410
# CHANNEL_CHURN_INDEX                            0.000424
# SERVICE_STATUS_MOVIE_FLAG                      0.000115
# L3M_AVG_GPRS_AMT                               0.000109
# DATA_BOOSTER_EVER_USE_FLAG                     0.000139
# BOOSTER_AMT                                    0.000041
# CWC_CATG7_CNT                                  0.000027
# CWC_CATG1_CNT                                  0.000030
# VIP_REDEEM_IND                                 0.000034
# CWC_CATG13_CNT                                 0.000006
# CWC_CATG9_CNT                                  0.000006
# CWC_CATG2_CNT                                  0.000013
# CWC_CATG8_CNT                                  0.000005
# CWC_CATG3_CNT                                  0.000007
# CWC_CATG12_CNT                                 0.000006
# CWC_CATG5_CNT                                  0.000003
# CWC_CATG10_CNT                                 0.000002
# CWC_CATG11_CNT                                 0.000001
# CWC_CATG4_CNT                                  0.000001
# GA_IND                                         0.000000
# SERVICE_STATUS_READING_FLAG                    0.000000
# SERVICE_STATUS_OMUSIC_FLAG                     0.000000
# CWC_CATG6_CNT                                  0.000000
# PAY_PENALTY_FLAG                               0.000000
#
# Groups                        No_significant_preference(instant_message)  \
# P3M_AVG_DATA_USAGE_MB                                           0.037884
# IMEI_MFG_NAME                                                   0.012700
# IMEI_MKT_NAME                                                   0.013325
# L3M_AVG_NET_INV_AMT                                             0.018940
# AGE                                                             0.015268
# CURR_DATA_BILL_PLAN_NAME                                        0.037623
# DATA_MONTHLY_FEE                                                0.030521
# FLAT_RATE_4G_IND                                                0.033065
# PROM_FLAT_RATE_4G_IND                                           0.037796
# PROM_CURR_PROMOTION_TYPE                                        0.020981
# TOTAL_MONTHLY_FEE                                               0.024011
# PROM_CURR_EXP_MONTH_CNT                                         0.014542
# TENURE_SCV                                                      0.012685
# L3M_AVG_MO_PSTN_CNT                                             0.044487
# L3M_AVG_MT_PSTN_CNT                                             0.025103
# PROM_CURR_PROMOTION_SUB_TYPE                                    0.015410
# L3M_AVG_MT_TTL_DUR                                              0.003925
# L3M_AVG_MO_PSTN_DUR                                             0.008045
# L3M_AVG_MT_PSTN_DUR                                             0.006019
# L3M_AVG_MT_OFFNET_DUR                                           0.006929
# L3M_AVG_MO_TTL_CNT                                              0.007563
# L3M_AVG_MT_TTL_CNT                                              0.007583
# L3M_AVG_MO_OFFNET_DUR                                           0.006336
# L3M_AVG_MO_OFFNET_CNT                                           0.016973
# L3M_AVG_MT_ONNET_CNT                                            0.016826
# L3M_AVG_MT_OFFNET_CNT                                           0.010952
# L3M_AVG_MO_TTL_DUR                                              0.003996
# L3M_AVG_MT_ONNET_DUR                                            0.004484
# L3M_AVG_PSTN_AMT                                                0.008335
# MOC_TWM_CNT                                                     0.042752
# ...                                                                  ...
# HS_LEASE_FEATURE_NAME                                           0.001490
# L3M_AVG_IDD_AMT                                                 0.000052
# VIP_TENURE                                                      0.002430
# SELFCARE_IND                                                    0.000290
# VIP_GRADE                                                       0.001966
# AUTOPAY_IND                                                     0.000210
# MSISDN_LAST_NP_OUT_IND                                          0.000879
# CHANNEL_CHURN_INDEX                                             0.000669
# SERVICE_STATUS_MOVIE_FLAG                                       0.000111
# L3M_AVG_GPRS_AMT                                                0.000092
# DATA_BOOSTER_EVER_USE_FLAG                                      0.000147
# BOOSTER_AMT                                                     0.000089
# CWC_CATG7_CNT                                                   0.000036
# CWC_CATG1_CNT                                                   0.000245
# VIP_REDEEM_IND                                                  0.000078
# CWC_CATG13_CNT                                                  0.000007
# CWC_CATG9_CNT                                                   0.000006
# CWC_CATG2_CNT                                                   0.000015
# CWC_CATG8_CNT                                                   0.000009
# CWC_CATG3_CNT                                                   0.000008
# CWC_CATG12_CNT                                                  0.000008
# CWC_CATG5_CNT                                                   0.000003
# CWC_CATG10_CNT                                                  0.000001
# CWC_CATG11_CNT                                                  0.000003
# CWC_CATG4_CNT                                                   0.000001
# GA_IND                                                          0.000000
# SERVICE_STATUS_READING_FLAG                                     0.000000
# SERVICE_STATUS_OMUSIC_FLAG                                      0.000000
# CWC_CATG6_CNT                                                   0.000000
# PAY_PENALTY_FLAG                                                0.000000
#
# Groups                          Portal  Social-media
# P3M_AVG_DATA_USAGE_MB         0.017588      0.021758
# IMEI_MFG_NAME                 0.104926      0.005810
# IMEI_MKT_NAME                 0.039544      0.005192
# L3M_AVG_NET_INV_AMT           0.014208      0.011762
# AGE                           0.016914      0.012808
# CURR_DATA_BILL_PLAN_NAME      0.023955      0.021053
# DATA_MONTHLY_FEE              0.021506      0.021045
# FLAT_RATE_4G_IND              0.024382      0.020651
# PROM_FLAT_RATE_4G_IND         0.024455      0.022917
# PROM_CURR_PROMOTION_TYPE      0.029518      0.015066
# TOTAL_MONTHLY_FEE             0.015791      0.015933
# PROM_CURR_EXP_MONTH_CNT       0.010251      0.009225
# TENURE_SCV                    0.013592      0.007639
# L3M_AVG_MO_PSTN_CNT           0.031241      0.037010
# L3M_AVG_MT_PSTN_CNT           0.036460      0.028203
# PROM_CURR_PROMOTION_SUB_TYPE  0.020148      0.010771
# L3M_AVG_MT_TTL_DUR            0.004430      0.003401
# L3M_AVG_MO_PSTN_DUR           0.006839      0.005862
# L3M_AVG_MT_PSTN_DUR           0.008968      0.007583
# L3M_AVG_MT_OFFNET_DUR         0.005434      0.004869
# L3M_AVG_MO_TTL_CNT            0.005827      0.009175
# L3M_AVG_MT_TTL_CNT            0.005518      0.007814
# L3M_AVG_MO_OFFNET_DUR         0.004379      0.005954
# L3M_AVG_MO_OFFNET_CNT         0.011502      0.027652
# L3M_AVG_MT_ONNET_CNT          0.009944      0.021103
# L3M_AVG_MT_OFFNET_CNT         0.007318      0.012156
# L3M_AVG_MO_TTL_DUR            0.003542      0.003395
# L3M_AVG_MT_ONNET_DUR          0.003097      0.004359
# L3M_AVG_PSTN_AMT              0.006066      0.004646
# MOC_TWM_CNT                   0.035453      0.068193
# ...                                ...           ...
# HS_LEASE_FEATURE_NAME         0.000732      0.000970
# L3M_AVG_IDD_AMT               0.000054      0.000045
# VIP_TENURE                    0.001099      0.002362
# SELFCARE_IND                  0.000085      0.000303
# VIP_GRADE                     0.001074      0.002053
# AUTOPAY_IND                   0.000190      0.000271
# MSISDN_LAST_NP_OUT_IND        0.001437      0.000525
# CHANNEL_CHURN_INDEX           0.000501      0.000462
# SERVICE_STATUS_MOVIE_FLAG     0.000121      0.000080
# L3M_AVG_GPRS_AMT              0.000093      0.000090
# DATA_BOOSTER_EVER_USE_FLAG    0.000095      0.000111
# BOOSTER_AMT                   0.000042      0.000048
# CWC_CATG7_CNT                 0.000055      0.000517
# CWC_CATG1_CNT                 0.000074      0.000614
# VIP_REDEEM_IND                0.000046      0.000085
# CWC_CATG13_CNT                0.000028      0.000010
# CWC_CATG9_CNT                 0.000005      0.000007
# CWC_CATG2_CNT                 0.000010      0.000014
# CWC_CATG8_CNT                 0.000010      0.000009
# CWC_CATG3_CNT                 0.000008      0.000008
# CWC_CATG12_CNT                0.000007      0.000009
# CWC_CATG5_CNT                 0.000003      0.000003
# CWC_CATG10_CNT                0.000002      0.000002
# CWC_CATG11_CNT                0.000000      0.000002
# CWC_CATG4_CNT                 0.000000      0.000002
# GA_IND                        0.000000      0.000000
# SERVICE_STATUS_READING_FLAG   0.000000      0.000000
# SERVICE_STATUS_OMUSIC_FLAG    0.000000      0.000000
# CWC_CATG6_CNT                 0.000000      0.000000
# PAY_PENALTY_FLAG              0.000000      0.000000
#
# [104 rows x 11 columns]

# %%
rank_df = df.rank(axis = 1, ascending=False).transpose()

# %%
rank_df = rank_df.sort_values('all' , ascending= True)

# %%
rank_df = rank_df.apply(np.int64)

# %%
rank_df = rank_df.drop("all", axis = 1)

# %%
rank_df
# Out:
# Groups                        Adult  Entertainment  Game  Infrequent_User  \
# P3M_AVG_DATA_USAGE_MB             1             15    21                1
# IMEI_MFG_NAME                    14             27    64               33
# IMEI_MKT_NAME                    13             23    62               17
# L3M_AVG_NET_INV_AMT              21             25    23                6
# AGE                              34             54    58               10
# CURR_DATA_BILL_PLAN_NAME          3              9    13                5
# DATA_MONTHLY_FEE                  4             10    15                2
# FLAT_RATE_4G_IND                  8              8    16                4
# PROM_FLAT_RATE_4G_IND             5              7    14                3
# PROM_CURR_PROMOTION_TYPE         16             16    22                8
# TOTAL_MONTHLY_FEE                12             17    18                7
# PROM_CURR_EXP_MONTH_CNT          25             31    25               15
# TENURE_SCV                       33             37    29               24
# L3M_AVG_MO_PSTN_CNT              18             11     4               12
# L3M_AVG_MT_PSTN_CNT              15             14    10               18
# PROM_CURR_PROMOTION_SUB_TYPE     22             22    24               11
# L3M_AVG_MT_TTL_DUR               55             48    54               41
# L3M_AVG_MO_PSTN_DUR              48             52    43               37
# L3M_AVG_MT_PSTN_DUR              40             51    47               44
# L3M_AVG_MT_OFFNET_DUR            59             43    51               51
# L3M_AVG_MO_TTL_CNT               56             26    28               21
# L3M_AVG_MT_TTL_CNT               57             35    50               32
# L3M_AVG_MO_OFFNET_DUR            61             49    53               47
# L3M_AVG_MO_OFFNET_CNT            35             13    17               30
# L3M_AVG_MT_ONNET_CNT             39             28    20               23
# L3M_AVG_MT_OFFNET_CNT            43             24    30               31
# L3M_AVG_MO_TTL_DUR               64             60    60               46
# L3M_AVG_MT_ONNET_DUR             63             58    57               60
# L3M_AVG_PSTN_AMT                 44             53    37               22
# MOC_TWM_CNT                       9              1     2               28
# ...                             ...            ...   ...              ...
# HS_LEASE_FEATURE_NAME            70             70    71               69
# L3M_AVG_IDD_AMT                  90             87    89               86
# VIP_TENURE                       68             67    61               76
# SELFCARE_IND                     83             88    87               70
# VIP_GRADE                        67             71    65               79
# AUTOPAY_IND                      79             84    82               82
# MSISDN_LAST_NP_OUT_IND           76             75    77               77
# CHANNEL_CHURN_INDEX              75             77    76               66
# SERVICE_STATUS_MOVIE_FLAG        86             86    86               84
# L3M_AVG_GPRS_AMT                 84             81    84               73
# DATA_BOOSTER_EVER_USE_FLAG       85             80    80               72
# BOOSTER_AMT                      87             82    88               78
# CWC_CATG7_CNT                    88             85    83               90
# CWC_CATG1_CNT                    80             79    79               88
# VIP_REDEEM_IND                   81             89    81               91
# CWC_CATG13_CNT                   94             97    95               95
# CWC_CATG9_CNT                    89             93    94               87
# CWC_CATG2_CNT                    91             90    93               92
# CWC_CATG8_CNT                    92             94    91               96
# CWC_CATG3_CNT                    96             91    92               93
# CWC_CATG12_CNT                   93             92    90               89
# CWC_CATG5_CNT                    95             95    96               94
# CWC_CATG10_CNT                   98             96    97               98
# CWC_CATG11_CNT                   97             98    98               97
# CWC_CATG4_CNT                    99             99    99               99
# CWC_CATG6_CNT                   100            100   100              100
# SERVICE_STATUS_OMUSIC_FLAG      102            102   102              103
# SERVICE_STATUS_READING_FLAG     102            102   102              101
# PAY_PENALTY_FLAG                102            102   102              103
# GA_IND                          102            102   102              103
#
# Groups                        InstantMessage-High  InstantMessage-SuperHigh  \
# P3M_AVG_DATA_USAGE_MB                          13                         8
# IMEI_MFG_NAME                                   5                        13
# IMEI_MKT_NAME                                   8                        15
# L3M_AVG_NET_INV_AMT                            23                        30
# AGE                                            33                        41
# CURR_DATA_BILL_PLAN_NAME                       10                        18
# DATA_MONTHLY_FEE                               15                        21
# FLAT_RATE_4G_IND                               11                        20
# PROM_FLAT_RATE_4G_IND                          12                        19
# PROM_CURR_PROMOTION_TYPE                       18                        24
# TOTAL_MONTHLY_FEE                              21                        28
# PROM_CURR_EXP_MONTH_CNT                        25                        32
# TENURE_SCV                                     37                        36
# L3M_AVG_MO_PSTN_CNT                             3                         9
# L3M_AVG_MT_PSTN_CNT                             9                         6
# PROM_CURR_PROMOTION_SUB_TYPE                   24                        33
# L3M_AVG_MT_TTL_DUR                             55                        55
# L3M_AVG_MO_PSTN_DUR                            30                        37
# L3M_AVG_MT_PSTN_DUR                            35                        27
# L3M_AVG_MT_OFFNET_DUR                          41                        44
# L3M_AVG_MO_TTL_CNT                             38                        39
# L3M_AVG_MT_TTL_CNT                             43                        47
# L3M_AVG_MO_OFFNET_DUR                          46                        45
# L3M_AVG_MO_OFFNET_CNT                          26                        25
# L3M_AVG_MT_ONNET_CNT                           19                        14
# L3M_AVG_MT_OFFNET_CNT                          28                        31
# L3M_AVG_MO_TTL_DUR                             54                        56
# L3M_AVG_MT_ONNET_DUR                           50                        52
# L3M_AVG_PSTN_AMT                               34                        51
# MOC_TWM_CNT                                     1                         1
# ...                                           ...                       ...
# HS_LEASE_FEATURE_NAME                          69                        75
# L3M_AVG_IDD_AMT                                78                        29
# VIP_TENURE                                     71                        72
# SELFCARE_IND                                   79                        82
# VIP_GRADE                                      70                        63
# AUTOPAY_IND                                    82                        79
# MSISDN_LAST_NP_OUT_IND                         80                        80
# CHANNEL_CHURN_INDEX                            81                        81
# SERVICE_STATUS_MOVIE_FLAG                      85                        84
# L3M_AVG_GPRS_AMT                               83                        87
# DATA_BOOSTER_EVER_USE_FLAG                     84                        85
# BOOSTER_AMT                                    88                        90
# CWC_CATG7_CNT                                  89                        89
# CWC_CATG1_CNT                                  86                        86
# VIP_REDEEM_IND                                 87                        83
# CWC_CATG13_CNT                                 90                        88
# CWC_CATG9_CNT                                  93                        94
# CWC_CATG2_CNT                                  91                        91
# CWC_CATG8_CNT                                  95                        92
# CWC_CATG3_CNT                                  92                        93
# CWC_CATG12_CNT                                 94                        95
# CWC_CATG5_CNT                                  96                        97
# CWC_CATG10_CNT                                 98                        96
# CWC_CATG11_CNT                                 97                        98
# CWC_CATG4_CNT                                  99                        99
# CWC_CATG6_CNT                                 100                       100
# SERVICE_STATUS_OMUSIC_FLAG                    102                       102
# SERVICE_STATUS_READING_FLAG                   102                       102
# PAY_PENALTY_FLAG                              102                       102
# GA_IND                                        102                       102
#
# Groups                        Lifestyle  No_significant_preference  \
# P3M_AVG_DATA_USAGE_MB                 1                         14
# IMEI_MFG_NAME                        39                          1
# IMEI_MKT_NAME                        36                          2
# L3M_AVG_NET_INV_AMT                  21                         21
# AGE                                  12                         28
# CURR_DATA_BILL_PLAN_NAME              2                          6
# DATA_MONTHLY_FEE                      5                          8
# FLAT_RATE_4G_IND                      7                         12
# PROM_FLAT_RATE_4G_IND                 4                         10
# PROM_CURR_PROMOTION_TYPE             15                          5
# TOTAL_MONTHLY_FEE                    13                         20
# PROM_CURR_EXP_MONTH_CNT              28                         27
# TENURE_SCV                           23                         33
# L3M_AVG_MO_PSTN_CNT                   8                         13
# L3M_AVG_MT_PSTN_CNT                  16                         16
# PROM_CURR_PROMOTION_SUB_TYPE         24                         22
# L3M_AVG_MT_TTL_DUR                   62                         43
# L3M_AVG_MO_PSTN_DUR                  44                         48
# L3M_AVG_MT_PSTN_DUR                  48                         40
# L3M_AVG_MT_OFFNET_DUR                53                         39
# L3M_AVG_MO_TTL_CNT                   42                         32
# L3M_AVG_MT_TTL_CNT                   52                         35
# L3M_AVG_MO_OFFNET_DUR                55                         47
# L3M_AVG_MO_OFFNET_CNT                29                         24
# L3M_AVG_MT_ONNET_CNT                 27                         31
# L3M_AVG_MT_OFFNET_CNT                37                         23
# L3M_AVG_MO_TTL_DUR                   61                         57
# L3M_AVG_MT_ONNET_DUR                 60                         56
# L3M_AVG_PSTN_AMT                     45                         46
# MOC_TWM_CNT                           3                          4
# ...                                 ...                        ...
# HS_LEASE_FEATURE_NAME                63                         72
# L3M_AVG_IDD_AMT                      89                         85
# VIP_TENURE                           67                         65
# SELFCARE_IND                         82                         79
# VIP_GRADE                            66                         70
# AUTOPAY_IND                          79                         81
# MSISDN_LAST_NP_OUT_IND               72                         78
# CHANNEL_CHURN_INDEX                  75                         77
# SERVICE_STATUS_MOVIE_FLAG            88                         83
# L3M_AVG_GPRS_AMT                     84                         84
# DATA_BOOSTER_EVER_USE_FLAG           80                         82
# BOOSTER_AMT                          83                         86
# CWC_CATG7_CNT                        85                         89
# CWC_CATG1_CNT                        81                         88
# VIP_REDEEM_IND                       87                         87
# CWC_CATG13_CNT                       95                         94
# CWC_CATG9_CNT                        94                         93
# CWC_CATG2_CNT                        90                         90
# CWC_CATG8_CNT                        91                         95
# CWC_CATG3_CNT                        92                         91
# CWC_CATG12_CNT                       93                         92
# CWC_CATG5_CNT                        96                         96
# CWC_CATG10_CNT                       97                         97
# CWC_CATG11_CNT                       99                         99
# CWC_CATG4_CNT                        98                         98
# CWC_CATG6_CNT                       100                        100
# SERVICE_STATUS_OMUSIC_FLAG          102                        102
# SERVICE_STATUS_READING_FLAG         102                        102
# PAY_PENALTY_FLAG                    102                        102
# GA_IND                              102                        102
#
# Groups                        No_significant_preference(instant_message)  \
# P3M_AVG_DATA_USAGE_MB                                                  5
# IMEI_MFG_NAME                                                         31
# IMEI_MKT_NAME                                                         29
# L3M_AVG_NET_INV_AMT                                                   18
# AGE                                                                   23
# CURR_DATA_BILL_PLAN_NAME                                               7
# DATA_MONTHLY_FEE                                                      11
# FLAT_RATE_4G_IND                                                       9
# PROM_FLAT_RATE_4G_IND                                                  6
# PROM_CURR_PROMOTION_TYPE                                              16
# TOTAL_MONTHLY_FEE                                                     13
# PROM_CURR_EXP_MONTH_CNT                                               24
# TENURE_SCV                                                            32
# L3M_AVG_MO_PSTN_CNT                                                    1
# L3M_AVG_MT_PSTN_CNT                                                   12
# PROM_CURR_PROMOTION_SUB_TYPE                                          22
# L3M_AVG_MT_TTL_DUR                                                    61
# L3M_AVG_MO_PSTN_DUR                                                   40
# L3M_AVG_MT_PSTN_DUR                                                   52
# L3M_AVG_MT_OFFNET_DUR                                                 46
# L3M_AVG_MO_TTL_CNT                                                    44
# L3M_AVG_MT_TTL_CNT                                                    43
# L3M_AVG_MO_OFFNET_DUR                                                 50
# L3M_AVG_MO_OFFNET_CNT                                                 19
# L3M_AVG_MT_ONNET_CNT                                                  20
# L3M_AVG_MT_OFFNET_CNT                                                 34
# L3M_AVG_MO_TTL_DUR                                                    60
# L3M_AVG_MT_ONNET_DUR                                                  57
# L3M_AVG_PSTN_AMT                                                      38
# MOC_TWM_CNT                                                            2
# ...                                                                  ...
# HS_LEASE_FEATURE_NAME                                                 71
# L3M_AVG_IDD_AMT                                                       88
# VIP_TENURE                                                            65
# SELFCARE_IND                                                          79
# VIP_GRADE                                                             69
# AUTOPAY_IND                                                           81
# MSISDN_LAST_NP_OUT_IND                                                75
# CHANNEL_CHURN_INDEX                                                   76
# SERVICE_STATUS_MOVIE_FLAG                                             84
# L3M_AVG_GPRS_AMT                                                      85
# DATA_BOOSTER_EVER_USE_FLAG                                            83
# BOOSTER_AMT                                                           86
# CWC_CATG7_CNT                                                         89
# CWC_CATG1_CNT                                                         80
# VIP_REDEEM_IND                                                        87
# CWC_CATG13_CNT                                                        94
# CWC_CATG9_CNT                                                         95
# CWC_CATG2_CNT                                                         90
# CWC_CATG8_CNT                                                         91
# CWC_CATG3_CNT                                                         92
# CWC_CATG12_CNT                                                        93
# CWC_CATG5_CNT                                                         96
# CWC_CATG10_CNT                                                        98
# CWC_CATG11_CNT                                                        97
# CWC_CATG4_CNT                                                         99
# CWC_CATG6_CNT                                                        100
# SERVICE_STATUS_OMUSIC_FLAG                                           102
# SERVICE_STATUS_READING_FLAG                                          102
# PAY_PENALTY_FLAG                                                     102
# GA_IND                                                               102
#
# Groups                        Portal  Social-media
# P3M_AVG_DATA_USAGE_MB             21            16
# IMEI_MFG_NAME                      1            48
# IMEI_MKT_NAME                      2            50
# L3M_AVG_NET_INV_AMT               28            25
# AGE                               22            23
# CURR_DATA_BILL_PLAN_NAME          13            18
# DATA_MONTHLY_FEE                  14            19
# FLAT_RATE_4G_IND                  12            20
# PROM_FLAT_RATE_4G_IND             11            15
# PROM_CURR_PROMOTION_TYPE           8            22
# TOTAL_MONTHLY_FEE                 26            21
# PROM_CURR_EXP_MONTH_CNT           36            29
# TENURE_SCV                        29            39
# L3M_AVG_MO_PSTN_CNT                6             6
# L3M_AVG_MT_PSTN_CNT                3            11
# PROM_CURR_PROMOTION_SUB_TYPE      15            28
# L3M_AVG_MT_TTL_DUR                54            60
# L3M_AVG_MO_PSTN_DUR               41            47
# L3M_AVG_MT_PSTN_DUR               38            41
# L3M_AVG_MT_OFFNET_DUR             49            52
# L3M_AVG_MO_TTL_CNT                46            30
# L3M_AVG_MT_TTL_CNT                48            38
# L3M_AVG_MO_OFFNET_DUR             55            46
# L3M_AVG_MO_OFFNET_CNT             34            12
# L3M_AVG_MT_ONNET_CNT              37            17
# L3M_AVG_MT_OFFNET_CNT             40            24
# L3M_AVG_MO_TTL_DUR                59            61
# L3M_AVG_MT_ONNET_DUR              64            56
# L3M_AVG_PSTN_AMT                  44            54
# MOC_TWM_CNT                        5             1
# ...                              ...           ...
# HS_LEASE_FEATURE_NAME             75            73
# L3M_AVG_IDD_AMT                   87            89
# VIP_TENURE                        72            65
# SELFCARE_IND                      83            81
# VIP_GRADE                         73            67
# AUTOPAY_IND                       79            82
# MSISDN_LAST_NP_OUT_IND            69            78
# CHANNEL_CHURN_INDEX               77            80
# SERVICE_STATUS_MOVIE_FLAG         80            87
# L3M_AVG_GPRS_AMT                  82            85
# DATA_BOOSTER_EVER_USE_FLAG        81            84
# BOOSTER_AMT                       89            88
# CWC_CATG7_CNT                     86            79
# CWC_CATG1_CNT                     84            77
# VIP_REDEEM_IND                    88            86
# CWC_CATG13_CNT                    90            91
# CWC_CATG9_CNT                     95            95
# CWC_CATG2_CNT                     92            90
# CWC_CATG8_CNT                     91            92
# CWC_CATG3_CNT                     93            94
# CWC_CATG12_CNT                    94            93
# CWC_CATG5_CNT                     96            96
# CWC_CATG10_CNT                    97            97
# CWC_CATG11_CNT                    99            98
# CWC_CATG4_CNT                     98            99
# CWC_CATG6_CNT                    100           100
# SERVICE_STATUS_OMUSIC_FLAG       102           102
# SERVICE_STATUS_READING_FLAG      102           102
# PAY_PENALTY_FLAG                 102           102
# GA_IND                           102           102
#
# [104 rows x 11 columns]

# %%
rank_df.to_csv(path + "rank_df.csv", encoding='utf-8')

# %%
df.groupby("Groups").count()
# Out:
#                                             ACTV_TYPE  AGE  \
# Groups
# Adult                                               1    1
# Entertainment                                       1    1
# Game                                                1    1
# Infrequent_User                                     1    1
# InstantMessage-High                                 1    1
# InstantMessage-SuperHigh                            1    1
# Lifestyle                                           1    1
# No_significant_preference                           1    1
# No_significant_preference(instant_message)          1    1
# Portal                                              1    1
# Social-media                                        1    1
# all                                                 1    1
#
#                                             APPLY_CURR_EBILL_SBILL_FLAG  \
# Groups
# Adult                                                                 1
# Entertainment                                                         1
# Game                                                                  1
# Infrequent_User                                                       1
# InstantMessage-High                                                   1
# InstantMessage-SuperHigh                                              1
# Lifestyle                                                             1
# No_significant_preference                                             1
# No_significant_preference(instant_message)                            1
# Portal                                                                1
# Social-media                                                          1
# all                                                                   1
#
#                                             AUTOPAY_IND  \
# Groups
# Adult                                                 1
# Entertainment                                         1
# Game                                                  1
# Infrequent_User                                       1
# InstantMessage-High                                   1
# InstantMessage-SuperHigh                              1
# Lifestyle                                             1
# No_significant_preference                             1
# No_significant_preference(instant_message)            1
# Portal                                                1
# Social-media                                          1
# all                                                   1
#
#                                             AVG_HS_USE_MONTH_EX_CURR  \
# Groups
# Adult                                                              1
# Entertainment                                                      1
# Game                                                               1
# Infrequent_User                                                    1
# InstantMessage-High                                                1
# InstantMessage-SuperHigh                                           1
# Lifestyle                                                          1
# No_significant_preference                                          1
# No_significant_preference(instant_message)                         1
# Portal                                                             1
# Social-media                                                       1
# all                                                                1
#
#                                             BILL_ZIP_CODE  BOOSTER_AMT  \
# Groups
# Adult                                                   1            1
# Entertainment                                           1            1
# Game                                                    1            1
# Infrequent_User                                         1            1
# InstantMessage-High                                     1            1
# InstantMessage-SuperHigh                                1            1
# Lifestyle                                               1            1
# No_significant_preference                               1            1
# No_significant_preference(instant_message)              1            1
# Portal                                                  1            1
# Social-media                                            1            1
# all                                                     1            1
#
#                                             CHANNEL_CHURN_INDEX  \
# Groups
# Adult                                                         1
# Entertainment                                                 1
# Game                                                          1
# Infrequent_User                                               1
# InstantMessage-High                                           1
# InstantMessage-SuperHigh                                      1
# Lifestyle                                                     1
# No_significant_preference                                     1
# No_significant_preference(instant_message)                    1
# Portal                                                        1
# Social-media                                                  1
# all                                                           1
#
#                                             CHURN_CLM_IND  \
# Groups
# Adult                                                   1
# Entertainment                                           1
# Game                                                    1
# Infrequent_User                                         1
# InstantMessage-High                                     1
# InstantMessage-SuperHigh                                1
# Lifestyle                                               1
# No_significant_preference                               1
# No_significant_preference(instant_message)              1
# Portal                                                  1
# Social-media                                            1
# all                                                     1
#
#                                             CURR_DATA_BILL_PLAN_NAME  \
# Groups
# Adult                                                              1
# Entertainment                                                      1
# Game                                                               1
# Infrequent_User                                                    1
# InstantMessage-High                                                1
# InstantMessage-SuperHigh                                           1
# Lifestyle                                                          1
# No_significant_preference                                          1
# No_significant_preference(instant_message)                         1
# Portal                                                             1
# Social-media                                                       1
# all                                                                1
#
#                                                    ...           \
# Groups                                             ...
# Adult                                              ...
# Entertainment                                      ...
# Game                                               ...
# Infrequent_User                                    ...
# InstantMessage-High                                ...
# InstantMessage-SuperHigh                           ...
# Lifestyle                                          ...
# No_significant_preference                          ...
# No_significant_preference(instant_message)         ...
# Portal                                             ...
# Social-media                                       ...
# all                                                ...
#
#                                             SERVICE_STATUS_OMUSIC_FLAG  \
# Groups
# Adult                                                                1
# Entertainment                                                        1
# Game                                                                 1
# Infrequent_User                                                      1
# InstantMessage-High                                                  1
# InstantMessage-SuperHigh                                             1
# Lifestyle                                                            1
# No_significant_preference                                            1
# No_significant_preference(instant_message)                           1
# Portal                                                               1
# Social-media                                                         1
# all                                                                  1
#
#                                             SERVICE_STATUS_READING_FLAG  \
# Groups
# Adult                                                                 1
# Entertainment                                                         1
# Game                                                                  1
# Infrequent_User                                                       1
# InstantMessage-High                                                   1
# InstantMessage-SuperHigh                                              1
# Lifestyle                                                             1
# No_significant_preference                                             1
# No_significant_preference(instant_message)                            1
# Portal                                                                1
# Social-media                                                          1
# all                                                                   1
#
#                                             SRV_TYPE_DESC  TENURE_SCV  \
# Groups
# Adult                                                   1           1
# Entertainment                                           1           1
# Game                                                    1           1
# Infrequent_User                                         1           1
# InstantMessage-High                                     1           1
# InstantMessage-SuperHigh                                1           1
# Lifestyle                                               1           1
# No_significant_preference                               1           1
# No_significant_preference(instant_message)              1           1
# Portal                                                  1           1
# Social-media                                            1           1
# all                                                     1           1
#
#                                             TOTAL_MONTHLY_FEE  VIP_GRADE  \
# Groups
# Adult                                                       1          1
# Entertainment                                               1          1
# Game                                                        1          1
# Infrequent_User                                             1          1
# InstantMessage-High                                         1          1
# InstantMessage-SuperHigh                                    1          1
# Lifestyle                                                   1          1
# No_significant_preference                                   1          1
# No_significant_preference(instant_message)                  1          1
# Portal                                                      1          1
# Social-media                                                1          1
# all                                                         1          1
#
#                                             VIP_REDEEM_IND  VIP_TENURE  \
# Groups
# Adult                                                    1           1
# Entertainment                                            1           1
# Game                                                     1           1
# Infrequent_User                                          1           1
# InstantMessage-High                                      1           1
# InstantMessage-SuperHigh                                 1           1
# Lifestyle                                                1           1
# No_significant_preference                                1           1
# No_significant_preference(instant_message)               1           1
# Portal                                                   1           1
# Social-media                                             1           1
# all                                                      1           1
#
#                                             VOICE_MONTHLY_FEE  \
# Groups
# Adult                                                       1
# Entertainment                                               1
# Game                                                        1
# Infrequent_User                                             1
# InstantMessage-High                                         1
# InstantMessage-SuperHigh                                    1
# Lifestyle                                                   1
# No_significant_preference                                   1
# No_significant_preference(instant_message)                  1
# Portal                                                      1
# Social-media                                                1
# all                                                         1
#
#                                             ZONE_ACTIVATION_IVR
# Groups
# Adult                                                         1
# Entertainment                                                 1
# Game                                                          1
# Infrequent_User                                               1
# InstantMessage-High                                           1
# InstantMessage-SuperHigh                                      1
# Lifestyle                                                     1
# No_significant_preference                                     1
# No_significant_preference(instant_message)                    1
# Portal                                                        1
# Social-media                                                  1
# all                                                           1
#
# [12 rows x 104 columns]
