# %%
import numpy as np
import pandas as pd
from time import time
from sklearn.cluster import KMeans
from pandas.computation import expressions as expr
import pprint as pp

# %%
# set configure
path = "./CDR_CONCAT/"
filename = "CDR_CONCAT_TABLE_4"
relative_filename = path + filename + ".csv"
# out_filename = "mds_mly_minus20160901"
# after the numeric_st_idx's number will be tranform to int64
numeric_st_idx = 1
n_clusters = 8

# %%
# read revise csv file and print cost time
# just load 5 data 
t0 = time()
df = pd.read_csv(relative_filename, error_bad_lines=False)
print("time for read csv: %.2f" % (time()-t0))
# Out:
# time for read csv: 4.14

# %%
df = df[['mo_workday_time','mo_holiday_time','mt_workday_time','mt_holiday_time']]
# df = df[['mo_workday_cnt','mo_workday_time','mo_holiday_cnt','mo_holiday_time', 'mt_workday_cnt','mt_workday_time','mt_holiday_cnt','mt_holiday_time']]

# %%
df.head()
# Out:
#    mo_workday_cnt  mo_workday_time  mo_holiday_cnt  mo_holiday_time  \
# 0              21             1989              11              453
# 1              32             2537              23             1700
# 2               2              146               7             1805
# 3              61             2291              37             1404
# 4              40             5366              23              842
#
#    mt_workday_cnt  mt_workday_time  mt_holiday_cnt  mt_holiday_time
# 0              23             1421               3              154
# 1              76            10633              25             1839
# 2              18              628              18              544
# 3              32             1172              26              769
# 4              45             2731              18              490

# %%
len(df)
# Out:
# 469623

# %%
df[df.columns[numeric_st_idx:]]
# Out:
#         mo_holiday_time  mt_workday_time  mt_holiday_time
# 0                   453             1421              154
# 1                  1700            10633             1839
# 2                  1805              628              544
# 3                  1404             1172              769
# 4                   842             2731              490
# 5                   628             2531              221
# 6                  1571             2759              941
# 7                   427             3420             1055
# 8                   860              970             4702
# 9                  1315              443               64
# 10                 1455                0               60
# 11                  275              955              361
# 12                  594             2379             3390
# 13                    0              375                0
# 14                 2286              484              385
# 15                 1479             8628             1254
# 16                  527              848              181
# 17                  389             3673              664
# 18                  457             2589              964
# 19                  747              134             1473
# 20                   14             1007              198
# 21                26833             2677              185
# 22                  150              107              252
# 23                 2061             5691             2038
# 24                  550             1977              637
# 25                   46               46              844
# 26                   85              151              279
# 27                 2405              561              644
# 28                  204            11600             1012
# 29                  349             3035              657
# ...                 ...              ...              ...
# 469593             1830              226              196
# 469594               24             1584             1588
# 469595             1053              197              504
# 469596              504             1105              243
# 469597              307             3332               65
# 469598              863              517              197
# 469599              870             3221              596
# 469600             1989              144              439
# 469601              312             1861              690
# 469602              404              484              334
# 469603             1314              322              185
# 469604             1082             4210             2629
# 469605              137              280                0
# 469606              820              635               17
# 469607             5721             3168             2077
# 469608             1864               39                0
# 469609             1936             5476             2241
# 469610              114             2171              333
# 469611              273              893              433
# 469612              397              627              224
# 469613              127              440              178
# 469614                0              522              138
# 469615             2098              489               67
# 469616                0             1754             1656
# 469617               15               74                0
# 469618             1095             1079              270
# 469619             1968              565              160
# 469620              535             4929              768
# 469621              755             3190             1003
# 469622              422             1499             1604
#
# [469623 rows x 3 columns]

# %%
t0 = time()
kmeans = KMeans(n_clusters=n_clusters, max_iter = 3000).fit(df.values)
# kmeans = KMeans(n_clusters=n_clusters).fit(df[df.columns[numeric_st_idx:]])
print("time for k mean csv: %.2f " % (time()-t0))
# Out:
# time for k mean csv: 14.81

# %%
cluster_result = {}
for i in range(n_clusters):
    cluster_result[i] = 0

for l in kmeans.labels_:
    cluster_result[l] += 1
pp.pprint(cluster_result)
# Out:
# {0: 1843, 1: 39445, 2: 100, 3: 178, 4: 412022, 5: 15677, 6: 16, 7: 342}

# %%
kmeans.cluster_centers_
# Out:
# array([[  2.82145262e+01,   2.21483597e+03,   1.21974311e+01,
#           8.68210811e+02,   2.96531379e+01,   2.34221487e+03,
#           1.15771155e+01,   8.29302068e+02],
#        [  2.70828877e+02,   4.69895225e+05,   1.06925134e+02,
#           1.76869102e+05,   3.47540107e+01,   4.19266310e+03,
#           1.37807487e+01,   1.18268984e+03],
#        [  2.23400597e+02,   4.04242354e+04,   6.84638425e+01,
#           1.22887387e+04,   3.59633652e+01,   3.09504189e+03,
#           1.35674224e+01,   1.04319964e+03],
#        [  4.13011364e+01,   3.37519318e+03,   1.55738636e+01,
#           1.41552841e+03,   2.48926136e+02,   4.23535261e+05,
#           9.54659091e+01,   1.68597136e+05],
#        [  3.16054656e+01,   2.59811475e+03,   1.33624186e+01,
#           9.81279359e+02,   1.93062134e+02,   2.68048196e+04,
#           5.33259455e+01,   7.24296030e+03]])

# %%
df.iloc[1][numeric_st_idx:]
# Out:
# VOICE_MO_HOUR_0_CNT           0
# VOICE_MO_HOUR_1_CNT           0
# VOICE_MO_HOUR_2_CNT           0
# VOICE_MO_HOUR_3_CNT           0
# VOICE_MO_HOUR_4_CNT           0
# VOICE_MO_HOUR_5_CNT           0
# VOICE_MO_HOUR_6_CNT           0
# VOICE_MO_HOUR_7_CNT           0
# VOICE_MO_HOUR_8_CNT           2
# VOICE_MO_HOUR_9_CNT           0
# VOICE_MO_HOUR_10_CNT          1
# VOICE_MO_HOUR_11_CNT          1
# VOICE_MO_HOUR_12_CNT          2
# VOICE_MO_HOUR_13_CNT          0
# VOICE_MO_HOUR_14_CNT          0
# VOICE_MO_HOUR_15_CNT          0
# VOICE_MO_HOUR_16_CNT          1
# VOICE_MO_HOUR_17_CNT          0
# VOICE_MO_HOUR_18_CNT          1
# VOICE_MO_HOUR_19_CNT          1
# VOICE_MO_HOUR_20_CNT          0
# VOICE_MO_HOUR_21_CNT          0
# VOICE_MO_HOUR_22_CNT          0
# VOICE_MO_HOUR_23_CNT          0
# VOICE_MO_HOUR_0_TIME          0
# VOICE_MO_HOUR_1_TIME          0
# VOICE_MO_HOUR_2_TIME          0
# VOICE_MO_HOUR_3_TIME          0
# VOICE_MO_HOUR_4_TIME          0
# VOICE_MO_HOUR_5_TIME          0
#                           ...
# VOICE_MO_HOUR_MON_TIME      534
# VOICE_MO_HOUR_TUE_TIME      109
# VOICE_MO_HOUR_WED_TIME      110
# VOICE_MO_HOUR_THU_TIME      178
# VOICE_MO_HOUR_FRI_TIME     1606
# VOICE_MO_HOUR_SAT_TIME      906
# workday_cnt                  32
# workday_time               2537
# holiday_cnt                  23
# holiday_time               1700
# Unnamed: 0.1                  1
# MINING_DW_SUBSCR_NO.3      1179
# VOICE_MT_SUN_CNT             10
# VOICE_MT_MON_CNT             20
# VOICE_MT_TUE_CNT             10
# VOICE_MT_WED_CNT             13
# VOICE_MT_THU_CNT             16
# VOICE_MT_FRI_CNT             17
# VOICE_MT_SAT_CNT             15
# VOICE_MT_SUN_TIME           406
# VOICE_MT_MON_TIME          1869
# VOICE_MT_TUE_TIME           427
# VOICE_MT_WED_TIME           595
# VOICE_MT_THU_TIME          1711
# VOICE_MT_FRI_TIME          6031
# VOICE_MT_SAT_TIME          1433
# workday_cnt.1                76
# workday_time.1            10633
# holiday_cnt.1                25
# holiday_time.1             1839
# Name: 1, Length: 137, dtype: int64

# %%
print(kmeans.predict(df.iloc[1][numeric_st_idx:]))
# Out:
# [2]
# C:\Users\VIPLAB\AppData\Local\conda\conda\envs\py36\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
df['label'] = kmeans.labels_

# %%
test_df = df.groupby('label')
test_df.mean()
# for index, row in test_df.iterrows():
#     print(index, row.values)
# for g in test_df.mean():
#     print(g)
# Out:
#        mo_workday_time  mo_holiday_time  mt_workday_time  mt_holiday_time
# label
# 0          2862.274552      1030.310906     68083.004883     20646.109604
# 1          2314.341691       893.748384     15759.746660      4204.726784
# 2        604196.850000    225031.610000      4641.130000      1197.040000
# 3          3340.668539      1397.735955    351295.955056    138887.500000
# 4          1936.312707       786.072884      1851.155659       702.345693
# 5         27429.737641      8267.300504      2892.365376       976.863239
# 6          3142.250000      1059.937500    999946.562500    387671.500000
# 7        203711.973684     73504.789474      3811.228070      1233.008772

# %%
del dask_df

# %%
del df
