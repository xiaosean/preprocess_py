# %%
import os.path
import numpy as np
import pandas as pd
from time import time

# %%
# set configure
path = "./CDR_MONTHLY_AGGR/"
# path = "./dna_Data/"

filename = "CDR_MO_WEEK_COMPLETED_revise_month_4_aggregate_workday"
relative_filename = path + filename + ".csv"
out_filename = path + filename + ".csv"
# after the numeric_st_idx's number will be tranform to int64
numeric_st_idx = 2
# pick the columns of u wants

# %%
# read revise csv file and print cost time
t0 = time()
df = pd.read_csv(relative_filename, error_bad_lines=False)
print("time for read csv: %.2f" % (time()-t0))
# Out:
# time for read csv: 12.18

# %%
df.head()
# Out:
#    MINING_DW_SUBSCR_NO  VOICE_MO_HOUR_MON_CNT  VOICE_MO_HOUR_TUE_CNT  \
# 0                 1171                      2                      5
# 1                 1179                     17                      3
# 2                 1181                      0                      0
# 3                11121                     11                     13
# 4                11131                     14                      4
#
#    VOICE_MO_HOUR_WED_CNT  VOICE_MO_HOUR_THU_CNT  VOICE_MO_HOUR_FRI_CNT  \
# 0                      4                      6                      4
# 1                      2                      6                      4
# 2                      1                      0                      1
# 3                     16                     13                      8
# 4                     11                      6                      5
#
#    VOICE_MO_HOUR_SAT_CNT  VOICE_MO_HOUR_SUN_CNT  VOICE_MO_HOUR_MON_TIME  \
# ...

# %%
df.rename(columns=lambda x: x.replace("HOUR_", ""), inplace=True)

# %%
df.head()
# Out:
#    MINING_DW_SUBSCR_NO  VOICE_MO_MON_CNT  VOICE_MO_TUE_CNT  VOICE_MO_WED_CNT  \
# 0                 1171                 2                 5                 4
# 1                 1179                17                 3                 2
# 2                 1181                 0                 0                 1
# 3                11121                11                13                16
# 4                11131                14                 4                11
#
#    VOICE_MO_THU_CNT  VOICE_MO_FRI_CNT  VOICE_MO_SAT_CNT  VOICE_MO_SUN_CNT  \
# 0                 6                 4                 9                 2
# 1                 6                 4                15                 8
# 2                 0                 1                 7                 0
# 3                13                 8                23                14
# 4                 6                 5                 9                14
#
# ...

# %%
len(df)
# Out:
# 4197861

# %%
# write to csv and no index
t0 = time()
# aggr_df.to_csv(out_filename + ".csv", index=False, encoding='utf-8')
df.to_csv(out_filename, index=False, encoding='utf-8')
print("time for output csv file: %.2f" % (time()-t0))
# Out:
# time for output csv file: 60.72
