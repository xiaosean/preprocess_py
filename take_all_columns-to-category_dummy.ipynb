# %%
import os.path
import numpy as np
import pandas as pd
from time import time

# %%
def save_dataframe(df, out_filename):
   # write to csv and no index
    t0 = time()
    df.to_csv(out_filename + ".csv", index=False, encoding='utf-8')
#     df.to_csv(out_filename + ".csv", encoding='utf-8')
    print("time for output csv file: %.2f" % (time()-t0))

# %%
# set configure
# path = "./CDR_MONTHLY_AGGR/"
path = "D:/NEW_DATA_FULL_2017_6_30/"
# path = "C:/Users/VIPLAB/Downloads/Spark_data/"
# path = "./"
filename = "MDS_April_All_SINGLE_SIM_COMPLETED"

# path = "./"
# filename = "dm_subscr_mtc_mly_COMPLETED_revise"
# relative_filename = path + filename + ".csv"
relative_filename = path + filename + ".txt"

# %%
wants_cols = [
 'MINING_DW_SUBSCR_NO',
  'SRV_TYPE_DESC',
 'GENDER_CODE',
 'AGE',
 'TENURE_SCV',
 'BILL_CITY_NAME',
 'DORMANT_MONTH_CNT_MKT',
 'IMEI_MFG_NAME',
 'IMEI_BAND',
 'CHURN_CLM_IND',
 'PTY_NP_IN_IND',
 'PTY_NP_OUT_IND',
 'MDS_CURR_RENEW_CNT',
 'PROM_CURR_EXP_MONTH_CNT',
 'CURR_PROM_COMMIT_MONTHS',
 'L1M_PROM_COMMIT_MONTHS',
 'NET_INV_AMT',
 'L1M_NET_INV_AMT',
 'L2M_NET_INV_AMT',
 'L3M_NET_INV_AMT',
 'AGENCY_AMT',
 'L3M_AVG_NET_INV_AMT',
 'MT_STM_AMT',
 'VOICE_RC_AMT',
 'DATA_RC_AMT',
 'ONNET_AMT',
 'OFFNETM_AMT',
 'PSTN_AMT',
 'INT_ROAM_AMT',
 'IDD_AMT',
 'DATA_INV_AMT',
 'VOICE_INV_AMT',
 'GOOGLE_PLAY_IND',
 'MO_TTL_DURATION',
 'MO_ONNET_DUR',
 'MO_OFFNET_DUR',
 'PSTN_DUR',
 'MO_TTL_COUNT',
 'MO_ONNET_CNT',
 'MO_OFFNET_CNT',
 'PSTN_CNT',
 'MT_TTL_DURATION',
 'MT_ONNET_DUR',
 'MT_OFFNET_DUR',
 'MT_PSTN_DUR',
 'MT_TTL_COUNT',
 'MT_ONNET_CNT',
 'MT_OFFNET_CNT',
 'MT_PSTN_CNT',
 'MOST_MO_OPERATOR',
 'MOST_MT_OPERATOR',
 'MOC_FET_DUR',
 'MOC_TWM_DUR',
 'MOC_CHM_DUR',
 'MOC_OTH_DUR',
 'MOC_PSTN_DUR',
 'MOST_MO_DUR',
 'MTC_FET_DUR',
 'MTC_TWM_DUR',
 'MTC_CHM_DUR',
 'MTC_PSTN_DUR',
 'MOST_MT_DUR',
 'CUST_TYPE',
 'FLAT_RATE_4G_IND',
 'FLAT_RATE_3G_IND',
 'VOICE_MONTHLY_FEE',
 'DATA_MONTHLY_FEE',
 'TOTAL_MONTHLY_FEE',
 'DATA_RATING_USAGE_MB',
 'HS_CHG_CNT',
 'AVG_HS_USE_MONTH'
]

# %%
# read csv file and print cost time
t0 = time()
df = pd.read_csv(relative_filename, usecols = wants_cols, error_bad_lines=False, sep = '\t')
# df = pd.read_csv(relative_filename, error_bad_lines=False, nrows = 10)
# df = pd.read_csv(relative_filename, error_bad_lines=False, sep = '\t', nrows = 100000)
# df = pd.read_csv(relative_filename, error_bad_lines=False, sep = '\t')
print("time for read csv: %.2f" % (time()-t0))
# Out:
# C:\Users\VIPLAB\AppData\Local\conda\conda\envs\keras\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (24,76,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# time for read csv: 43.97

# %% [markdown]
# # merge group

# %%
# set configure
# path = "../DATA_FULL/"
# path = "./"
# filename = "DNA_KMEANS_RESULT_ID_NEW"
path = "./"
filename = "Groups_ID_0712"
relative_filename = path + filename + ".csv"
# relative_filename = path + filename + ".txt"
group_df =  pd.read_csv(relative_filename, usecols = ["MINING_DW_SUBSCR_NO","Groups"], error_bad_lines=False)
group_df = pd.merge(df, group_df, on='MINING_DW_SUBSCR_NO', how='inner')
group_df = group_df.set_index("MINING_DW_SUBSCR_NO")

# %%
group_df.head()
# Out:
#                      SRV_TYPE_DESC GENDER_CODE AGE  TENURE_SCV BILL_CITY_NAME  \
# MINING_DW_SUBSCR_NO
# 8134330931           F-POSTPAID-4G           F  44        21.0            臺北市
# 2118544651           F-POSTPAID-4G           F  58       226.0            新北市
# 10000337216          F-POSTPAID-4G           M  48         7.0            高雄市
# 3133428916           F-POSTPAID-3G           F  27        24.1            基隆市
# 3135493626           F-POSTPAID-4G           M  27        16.9            新北市
#
#                      DORMANT_MONTH_CNT_MKT  \
# MINING_DW_SUBSCR_NO
# 8134330931                               0
# 2118544651                               0
# 10000337216                              0
# 3133428916                               0
# 3135493626                               0
#
#                                                          IMEI_MFG_NAME  \
# MINING_DW_SUBSCR_NO
# 8134330931           SAMSUNG                                       ...
# 2118544651           ASUS                                          ...
# 10000337216          Sony                                          ...
# 3133428916           Apple                                         ...
# 3135493626           SAMSUNG                                       ...
#
#                     IMEI_BAND CHURN_CLM_IND PTY_NP_IN_IND  \
# MINING_DW_SUBSCR_NO
# 8134330931                 4G             W             N
# 2118544651                 4G             G             N
# 10000337216                4G             G             Y
# 3133428916                 4G             G             Y
# 3135493626                 4G             G             Y
#
#                                ...            CUST_TYPE  FLAT_RATE_4G_IND  \
# MINING_DW_SUBSCR_NO            ...
# 8134330931                     ...                   VD                 Y
# 2118544651                     ...                   VD                 Y
# 10000337216                    ...                   VD                 Y
# 3133428916                     ...                   VD                 N
# 3135493626                     ...                   VD                 Y
#
#                     FLAT_RATE_3G_IND VOICE_MONTHLY_FEE DATA_MONTHLY_FEE  \
# MINING_DW_SUBSCR_NO
# 8134330931                         N                 0             1199
# 2118544651                         N                 0              599
# 10000337216                        N                 0             1399
# 3133428916                         Y               398              770
# 3135493626                         N                 0              799
#
#                      TOTAL_MONTHLY_FEE  DATA_RATING_USAGE_MB  HS_CHG_CNT  \
# MINING_DW_SUBSCR_NO
# 8134330931                        1199                 17529           1
# 2118544651                         599                   633           3
# 10000337216                       1399                 26148           ?
# 3133428916                        1168                 29813           1
# 3135493626                         799                 12913           ?
#
#                      AVG_HS_USE_MONTH                    Groups
# MINING_DW_SUBSCR_NO
# 8134330931                        7.0        InstantMessage-Low
# 2118544651                       33.0           Infrequent_User
# 10000337216                         ?  No_ignificant_preference
# 3133428916                        6.0  No_ignificant_preference
# 3135493626                          ?        InstantMessage-Low
#
# [5 rows x 71 columns]

# %%
len(group_df)
# Out:
# 1884095

# %%
len(group_df.columns)
# Out:
# 71

# %%
list(group_df.columns)
# Out:
# ['SRV_TYPE_DESC',
#  'GENDER_CODE',
#  'AGE',
#  'TENURE_SCV',
#  'BILL_CITY_NAME',
#  'DORMANT_MONTH_CNT_MKT',
#  'IMEI_MFG_NAME',
#  'IMEI_BAND',
#  'CHURN_CLM_IND',
#  'PTY_NP_IN_IND',
#  'PTY_NP_OUT_IND',
#  'MDS_CURR_RENEW_CNT',
#  'PROM_CURR_EXP_MONTH_CNT',
#  'CURR_PROM_COMMIT_MONTHS',
#  'L1M_PROM_COMMIT_MONTHS',
#  'NET_INV_AMT',
#  'L1M_NET_INV_AMT',
#  'L2M_NET_INV_AMT',
#  'L3M_NET_INV_AMT',
#  'AGENCY_AMT',
#  'L3M_AVG_NET_INV_AMT',
#  'MT_STM_AMT',
#  'VOICE_RC_AMT',
#  'DATA_RC_AMT',
#  'ONNET_AMT',
#  'OFFNETM_AMT',
#  'PSTN_AMT',
#  'INT_ROAM_AMT',
#  'IDD_AMT',
#  'DATA_INV_AMT',
#  'VOICE_INV_AMT',
#  'GOOGLE_PLAY_IND',
#  'MO_TTL_DURATION',
#  'MO_ONNET_DUR',
#  'MO_OFFNET_DUR',
#  'PSTN_DUR',
#  'MO_TTL_COUNT',
#  'MO_ONNET_CNT',
#  'MO_OFFNET_CNT',
#  'PSTN_CNT',
#  'MT_TTL_DURATION',
#  'MT_ONNET_DUR',
#  'MT_OFFNET_DUR',
#  'MT_PSTN_DUR',
#  'MT_TTL_COUNT',
#  'MT_ONNET_CNT',
#  'MT_OFFNET_CNT',
#  'MT_PSTN_CNT',
#  'MOST_MO_OPERATOR',
#  'MOST_MT_OPERATOR',
#  'MOC_FET_DUR',
#  'MOC_TWM_DUR',
#  'MOC_CHM_DUR',
#  'MOC_OTH_DUR',
#  'MOC_PSTN_DUR',
#  'MOST_MO_DUR',
#  'MTC_FET_DUR',
#  'MTC_TWM_DUR',
#  'MTC_CHM_DUR',
#  'MTC_PSTN_DUR',
#  'MOST_MT_DUR',
#  'CUST_TYPE',
#  'FLAT_RATE_4G_IND',
#  'FLAT_RATE_3G_IND',
#  'VOICE_MONTHLY_FEE',
#  'DATA_MONTHLY_FEE',
#  'TOTAL_MONTHLY_FEE',
#  'DATA_RATING_USAGE_MB',
#  'HS_CHG_CNT',
#  'AVG_HS_USE_MONTH',
#  'Groups']

# %%
# non 
pick_columns = list(group_df.columns)

# %%
pick_columns.remove("Groups")

# %%
pick_columns
# Out:
# ['SRV_TYPE_DESC',
#  'GENDER_CODE',
#  'AGE',
#  'TENURE_SCV',
#  'BILL_CITY_NAME',
#  'DORMANT_MONTH_CNT_MKT',
#  'IMEI_MFG_NAME',
#  'IMEI_BAND',
#  'CHURN_CLM_IND',
#  'PTY_NP_IN_IND',
#  'PTY_NP_OUT_IND',
#  'MDS_CURR_RENEW_CNT',
#  'PROM_CURR_EXP_MONTH_CNT',
#  'CURR_PROM_COMMIT_MONTHS',
#  'L1M_PROM_COMMIT_MONTHS',
#  'NET_INV_AMT',
#  'L1M_NET_INV_AMT',
#  'L2M_NET_INV_AMT',
#  'L3M_NET_INV_AMT',
#  'AGENCY_AMT',
#  'L3M_AVG_NET_INV_AMT',
#  'MT_STM_AMT',
#  'VOICE_RC_AMT',
#  'DATA_RC_AMT',
#  'ONNET_AMT',
#  'OFFNETM_AMT',
#  'PSTN_AMT',
#  'INT_ROAM_AMT',
#  'IDD_AMT',
#  'DATA_INV_AMT',
#  'VOICE_INV_AMT',
#  'GOOGLE_PLAY_IND',
#  'MO_TTL_DURATION',
#  'MO_ONNET_DUR',
#  'MO_OFFNET_DUR',
#  'PSTN_DUR',
#  'MO_TTL_COUNT',
#  'MO_ONNET_CNT',
#  'MO_OFFNET_CNT',
#  'PSTN_CNT',
#  'MT_TTL_DURATION',
#  'MT_ONNET_DUR',
#  'MT_OFFNET_DUR',
#  'MT_PSTN_DUR',
#  'MT_TTL_COUNT',
#  'MT_ONNET_CNT',
#  'MT_OFFNET_CNT',
#  'MT_PSTN_CNT',
#  'MOST_MO_OPERATOR',
#  'MOST_MT_OPERATOR',
#  'MOC_FET_DUR',
#  'MOC_TWM_DUR',
#  'MOC_CHM_DUR',
#  'MOC_OTH_DUR',
#  'MOC_PSTN_DUR',
#  'MOST_MO_DUR',
#  'MTC_FET_DUR',
#  'MTC_TWM_DUR',
#  'MTC_CHM_DUR',
#  'MTC_PSTN_DUR',
#  'MOST_MT_DUR',
#  'CUST_TYPE',
#  'FLAT_RATE_4G_IND',
#  'FLAT_RATE_3G_IND',
#  'VOICE_MONTHLY_FEE',
#  'DATA_MONTHLY_FEE',
#  'TOTAL_MONTHLY_FEE',
#  'DATA_RATING_USAGE_MB',
#  'HS_CHG_CNT',
#  'AVG_HS_USE_MONTH']

# %%
dummy_df = pd.get_dummies(group_df[pick_columns])

# %%
dummy_df.head()
# Out:
#                      TENURE_SCV  DORMANT_MONTH_CNT_MKT  MDS_CURR_RENEW_CNT  \
# MINING_DW_SUBSCR_NO
# 8134330931                 21.0                      0                   2
# 2118544651                226.0                      0                   2
# 10000337216                 7.0                      0                   0
# 3133428916                 24.1                      0                   0
# 3135493626                 16.9                      0                   0
#
#                      NET_INV_AMT  L1M_NET_INV_AMT  L2M_NET_INV_AMT  \
# MINING_DW_SUBSCR_NO
# 8134330931                203.70           518.41           497.45
# 2118544651                499.00           499.00           507.30
# 10000337216              1449.90          1446.00          1429.00
# 3133428916                698.00           698.00           713.41
# 3135493626                711.99           721.59           711.89
#
#                      L3M_NET_INV_AMT  AGENCY_AMT  L3M_AVG_NET_INV_AMT  \
# MINING_DW_SUBSCR_NO
# 8134330931                    589.48       150.0               406.52
# 2118544651                    512.90         0.0               501.77
# 10000337216                  1441.60         0.0              1441.63
# 3133428916                    698.00         0.0               703.14
# 3135493626                    697.99         0.0               715.16
#
#                      MT_STM_AMT         ...          AVG_HS_USE_MONTH_91.0  \
# MINING_DW_SUBSCR_NO                     ...
# 8134330931               645.24         ...                              0
# 2118544651                 1.29         ...                              0
# 10000337216               91.16         ...                              0
# 3133428916                22.32         ...                              0
# 3135493626                 2.43         ...                              0
#
#                      AVG_HS_USE_MONTH_92.0  AVG_HS_USE_MONTH_93.0  \
# MINING_DW_SUBSCR_NO
# 8134330931                               0                      0
# 2118544651                               0                      0
# 10000337216                              0                      0
# 3133428916                               0                      0
# 3135493626                               0                      0
#
#                      AVG_HS_USE_MONTH_94.0  AVG_HS_USE_MONTH_95.0  \
# MINING_DW_SUBSCR_NO
# 8134330931                               0                      0
# 2118544651                               0                      0
# 10000337216                              0                      0
# 3133428916                               0                      0
# 3135493626                               0                      0
#
#                      AVG_HS_USE_MONTH_96.0  AVG_HS_USE_MONTH_97.0  \
# MINING_DW_SUBSCR_NO
# 8134330931                               0                      0
# 2118544651                               0                      0
# 10000337216                              0                      0
# 3133428916                               0                      0
# 3135493626                               0                      0
#
#                      AVG_HS_USE_MONTH_98.0  AVG_HS_USE_MONTH_99.0  \
# MINING_DW_SUBSCR_NO
# 8134330931                               0                      0
# 2118544651                               0                      0
# 10000337216                              0                      0
# 3133428916                               0                      0
# 3135493626                               0                      0
#
#                      AVG_HS_USE_MONTH_?
# MINING_DW_SUBSCR_NO
# 8134330931                            0
# 2118544651                            0
# 10000337216                           1
# 3133428916                            0
# 3135493626                            1
#
# [5 rows x 1034 columns]

# %%
len(dummy_df.columns)
# Out:
# 1034

# %%
dummy_df["Groups"] = group_df["Groups"]

# %%
len(dummy_df.columns)
# Out:
# 1035

# %%
dummy_df.groupby("Groups").count()
# Out:
#                           TENURE_SCV  DORMANT_MONTH_CNT_MKT  \
# Groups
# Adult                          54309                  54309
# Game                           87618                  87618
# HomeLife                       74949                  74949
# Infrequent_User               145107                 145107
# InstantMessage-High           424699                 424699
# InstantMessage-Low            431903                 431903
# Map                           103786                 103786
# News                           57174                  57174
# No_ignificant_preference      266966                 266966
# Portal                         98614                  98614
# Social-media                  138970                 138970
#
#                           MDS_CURR_RENEW_CNT  NET_INV_AMT  L1M_NET_INV_AMT  \
# Groups
# Adult                                  54309        54309            54309
# Game                                   87618        87618            87618
# HomeLife                               74949        74949            74949
# Infrequent_User                       145107       145107           145107
# InstantMessage-High                   424699       424699           424699
# InstantMessage-Low                    431903       431903           431903
# Map                                   103786       103786           103786
# News                                   57174        57174            57174
# No_ignificant_preference              266966       266966           266966
# Portal                                 98614        98614            98614
# Social-media                          138970       138970           138970
#
#                           L2M_NET_INV_AMT  L3M_NET_INV_AMT  AGENCY_AMT  \
# Groups
# Adult                               54309            54309       54309
# Game                                87618            87618       87618
# HomeLife                            74949            74949       74949
# Infrequent_User                    145107           145107      145107
# InstantMessage-High                424699           424699      424699
# InstantMessage-Low                 431903           431903      431903
# Map                                103786           103786      103786
# News                                57174            57174       57174
# No_ignificant_preference           266966           266966      266966
# Portal                              98614            98614       98614
# Social-media                       138970           138970      138970
#
#                           L3M_AVG_NET_INV_AMT  MT_STM_AMT         ...          \
# Groups                                                            ...
# Adult                                   54309       54309         ...
# Game                                    87618       87618         ...
# HomeLife                                74949       74949         ...
# Infrequent_User                        145107      145107         ...
# InstantMessage-High                    424699      424699         ...
# InstantMessage-Low                     431903      431903         ...
# Map                                    103786      103786         ...
# News                                    57174       57174         ...
# No_ignificant_preference               266966      266966         ...
# Portal                                  98614       98614         ...
# Social-media                           138970      138970         ...
#
#                           AVG_HS_USE_MONTH_91.0  AVG_HS_USE_MONTH_92.0  \
# Groups
# Adult                                     54309                  54309
# Game                                      87618                  87618
# HomeLife                                  74949                  74949
# Infrequent_User                          145107                 145107
# InstantMessage-High                      424699                 424699
# InstantMessage-Low                       431903                 431903
# Map                                      103786                 103786
# News                                      57174                  57174
# No_ignificant_preference                 266966                 266966
# Portal                                    98614                  98614
# Social-media                             138970                 138970
#
#                           AVG_HS_USE_MONTH_93.0  AVG_HS_USE_MONTH_94.0  \
# Groups
# Adult                                     54309                  54309
# Game                                      87618                  87618
# HomeLife                                  74949                  74949
# Infrequent_User                          145107                 145107
# InstantMessage-High                      424699                 424699
# InstantMessage-Low                       431903                 431903
# Map                                      103786                 103786
# News                                      57174                  57174
# No_ignificant_preference                 266966                 266966
# Portal                                    98614                  98614
# Social-media                             138970                 138970
#
#                           AVG_HS_USE_MONTH_95.0  AVG_HS_USE_MONTH_96.0  \
# Groups
# Adult                                     54309                  54309
# Game                                      87618                  87618
# HomeLife                                  74949                  74949
# Infrequent_User                          145107                 145107
# InstantMessage-High                      424699                 424699
# InstantMessage-Low                       431903                 431903
# Map                                      103786                 103786
# News                                      57174                  57174
# No_ignificant_preference                 266966                 266966
# Portal                                    98614                  98614
# Social-media                             138970                 138970
#
#                           AVG_HS_USE_MONTH_97.0  AVG_HS_USE_MONTH_98.0  \
# Groups
# Adult                                     54309                  54309
# Game                                      87618                  87618
# HomeLife                                  74949                  74949
# Infrequent_User                          145107                 145107
# InstantMessage-High                      424699                 424699
# InstantMessage-Low                       431903                 431903
# Map                                      103786                 103786
# News                                      57174                  57174
# No_ignificant_preference                 266966                 266966
# Portal                                    98614                  98614
# Social-media                             138970                 138970
#
#                           AVG_HS_USE_MONTH_99.0  AVG_HS_USE_MONTH_?
# Groups
# Adult                                     54309               54309
# Game                                      87618               87618
# HomeLife                                  74949               74949
# Infrequent_User                          145107              145107
# InstantMessage-High                      424699              424699
# InstantMessage-Low                       431903              431903
# Map                                      103786              103786
# News                                      57174               57174
# No_ignificant_preference                 266966              266966
# Portal                                    98614               98614
# Social-media                             138970              138970
#
# [11 rows x 1034 columns]

# %%
save_dataframe(dummy_df, path  + "0714_april_marketing_anylze_full_table_group12_select_category")
# Out:
# time for output csv file: 632.75

# %%
from mailerWithUtf8 import mail
test=mail()
test.main("marketing finished", "0713 done")
# Out:
# Start Send Mail
# User Email : a - DONE
# User Email : a - DONE
# User Email : 2 - DONE
# User Email : 6 - DONE
# User Email : 3 - DONE
# User Email : 6 - DONE
# User Email : 5 - DONE
# User Email : 5 - DONE
# User Email : 6 - DONE
# User Email : 6 - DONE
# User Email : @ - DONE
# User Email : g - DONE
# User Email : m - DONE
# User Email : a - DONE
# User Email : i - DONE
# User Email : l - DONE
# User Email : . - DONE
# User Email : c - DONE
# User Email : o - DONE
# User Email : m - DONE
# Finish Send Mail

# %%
# user_df.sort_values(["AGE"], inplace = True)
numeric_df = numeric_df.set_index("MINING_DW_SUBSCR_NO")
numeric_df.sort_index(inplace = True)
numeric_df["Groups"] = np.nan

# %%
numeric_df.head()
# Out:
#                      RENEW_IND  GA_IND  CHURN_IND  SUSPEND_IND  \
# MINING_DW_SUBSCR_NO
# 1179                         0       0          0            0
# 1181                         0       0          0            0
# 11121                        0       0          0            0
# 11145                        0       0          0            0
# 11149                        0       0          0            0
#
#                      P6M_AVG_NET_INV_AMT  TENURE_SCV  CHURN_INDEX  FETNET_IND  \
# MINING_DW_SUBSCR_NO
# 1179                             1088.04       188.2            0           0
# 1181                              515.67       188.2            0           0
# 11121                            1718.87       188.2            0           1
# 11145                            1300.15       188.2            0           0
# 11149                             656.37       188.2            0           0
#
#                      DORMANT_MONTH_CNT_MKT  HAPPYGO_IND   ...    \
# MINING_DW_SUBSCR_NO                                       ...
# 1179                                     0            0   ...
# 1181                                     0            0   ...
# 11121                                    0            1   ...
# 11145                                    0            1   ...
# 11149                                    0            0   ...
#
#                      EVER_PSTN_MONTH_APPLY_CANCEL_FLAG  VIP_REDEEM_IND  \
# MINING_DW_SUBSCR_NO
# 1179                                                 0               0
# 1181                                                 0               0
# 11121                                                0               0
# 11145                                                0               0
# 11149                                                0               0
#
#                      VIP_MSISDN_CHG_IND  PAY_PENALTY_FLAG  \
# MINING_DW_SUBSCR_NO
# 1179                                  0                 0
# 1181                                  0                 0
# 11121                                 0                 0
# 11145                                 0                 0
# 11149                                 0                 0
#
#                      DATA_RATING_USAGE_MB  SELFCARE_IND  \
# MINING_DW_SUBSCR_NO
# 1179                                 2993             1
# 1181                                 2427             0
# 11121                                2192             1
# 11145                                2152             1
# 11149                                1653             1
#
#                      RETAIL_STORE_CHURN_FLAG  RETAIL_STORE_CHURN_DEPUTY_FALG  \
# MINING_DW_SUBSCR_NO
# 1179                                       0                               0
# 1181                                       0                               0
# 11121                                      0                               0
# 11145                                      0                               0
# 11149                                      0                               0
#
#                      SPAUTH_IND  Groups
# MINING_DW_SUBSCR_NO
# 1179                          0     NaN
# 1181                          0     NaN
# 11121                         0     NaN
# 11145                         0     NaN
# 11149                         0     NaN
#
# [5 rows x 134 columns]

# %% [markdown]
# # LOAD MINING USER's Group

# %%
path = "./"
relative_filename = path + "DNA_KMEANS_RESULT_ID_NEW" + ".csv"
wants_cols = ["MINING_DW_SUBSCR_NO", "Groups"]
group_df =  pd.read_csv(relative_filename, error_bad_lines=False, usecols = wants_cols)

# %%
group_df = group_df.set_index("MINING_DW_SUBSCR_NO")
group_df.sort_index(inplace = True)

# %%
marketing_group = numeric_df[['Groups']]
marketing_group.update(group_df)
numeric_df[['Groups']] = marketing_group
# Out:
# C:\Users\VIPLAB\AppData\Local\conda\conda\envs\py36\lib\site-packages\pandas\core\frame.py:3863: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   raise_on_error=True)

# %%
numeric_df.head()
# Out:
#                      RENEW_IND  GA_IND  CHURN_IND  SUSPEND_IND  \
# MINING_DW_SUBSCR_NO
# 1179                         0       0          0            0
# 1181                         0       0          0            0
# 11121                        0       0          0            0
# 11145                        0       0          0            0
# 11149                        0       0          0            0
#
#                      P6M_AVG_NET_INV_AMT  TENURE_SCV  CHURN_INDEX  FETNET_IND  \
# MINING_DW_SUBSCR_NO
# 1179                             1088.04       188.2            0           0
# 1181                              515.67       188.2            0           0
# 11121                            1718.87       188.2            0           1
# 11145                            1300.15       188.2            0           0
# 11149                             656.37       188.2            0           0
#
#                      DORMANT_MONTH_CNT_MKT  HAPPYGO_IND   ...    \
# MINING_DW_SUBSCR_NO                                       ...
# 1179                                     0            0   ...
# 1181                                     0            0   ...
# 11121                                    0            1   ...
# 11145                                    0            1   ...
# 11149                                    0            0   ...
#
#                      EVER_PSTN_MONTH_APPLY_CANCEL_FLAG  VIP_REDEEM_IND  \
# MINING_DW_SUBSCR_NO
# 1179                                                 0               0
# 1181                                                 0               0
# 11121                                                0               0
# 11145                                                0               0
# 11149                                                0               0
#
#                      VIP_MSISDN_CHG_IND  PAY_PENALTY_FLAG  \
# MINING_DW_SUBSCR_NO
# 1179                                  0                 0
# 1181                                  0                 0
# 11121                                 0                 0
# 11145                                 0                 0
# 11149                                 0                 0
#
#                      DATA_RATING_USAGE_MB  SELFCARE_IND  \
# MINING_DW_SUBSCR_NO
# 1179                                 2993             1
# 1181                                 2427             0
# 11121                                2192             1
# 11145                                2152             1
# 11149                                1653             1
#
#                      RETAIL_STORE_CHURN_FLAG  RETAIL_STORE_CHURN_DEPUTY_FALG  \
# MINING_DW_SUBSCR_NO
# 1179                                       0                               0
# 1181                                       0                               0
# 11121                                      0                               0
# 11145                                      0                               0
# 11149                                      0                               0
#
#                      SPAUTH_IND  Groups
# MINING_DW_SUBSCR_NO
# 1179                          0  seldom
# 1181                          0       2
# 11121                         0       3
# 11145                         0  seldom
# 11149                         0       2
#
# [5 rows x 134 columns]

# %%
numeric_df.groupby("Groups").count()
# Out:
#         RENEW_IND  GA_IND  CHURN_IND  SUSPEND_IND  P6M_AVG_NET_INV_AMT  \
# Groups
# 1          407597  407597     407597       407597               407597
# 2          184644  184644     184644       184644               184644
# 3          105809  105809     105809       105809               105809
# 4          116958  116958     116958       116958               116958
# 5          110474  110474     110474       110474               110474
# 6          146047  146047     146047       146047               146047
# 7          164149  164149     164149       164149               164149
# 8          490166  490166     490166       490166               490166
# None       531990  531990     531990       531990               531990
# seldom     338963  338963     338963       338963               338963
#
#         TENURE_SCV  CHURN_INDEX  FETNET_IND  DORMANT_MONTH_CNT_MKT  \
# Groups
# 1           407597       407597      407597                 407597
# 2           184644       184644      184644                 184644
# 3           105809       105809      105809                 105809
# 4           116958       116958      116958                 116958
# 5           110474       110474      110474                 110474
# 6           146047       146047      146047                 146047
# 7           164149       164149      164149                 164149
# 8           490166       490166      490166                 490166
# None        531990       531990      531990                 531990
# seldom      338963       338963      338963                 338963
#
#         HAPPYGO_IND     ...      EVER_PSTN_FEATURE_FLAG  \
# Groups                  ...
# 1            407597     ...                      407597
# 2            184644     ...                      184644
# 3            105809     ...                      105809
# 4            116958     ...                      116958
# 5            110474     ...                      110474
# 6            146047     ...                      146047
# 7            164149     ...                      164149
# 8            490166     ...                      490166
# None         531990     ...                      531990
# seldom       338963     ...                      338963
#
#         EVER_PSTN_MONTH_APPLY_CANCEL_FLAG  VIP_REDEEM_IND  VIP_MSISDN_CHG_IND  \
# Groups
# 1                                  407597          407597              407597
# 2                                  184644          184644              184644
# 3                                  105809          105809              105809
# 4                                  116958          116958              116958
# 5                                  110474          110474              110474
# 6                                  146047          146047              146047
# 7                                  164149          164149              164149
# 8                                  490166          490166              490166
# None                               531990          531990              531990
# seldom                             338963          338963              338963
#
#         PAY_PENALTY_FLAG  DATA_RATING_USAGE_MB  SELFCARE_IND  \
# Groups
# 1                 407597                407597        407597
# 2                 184644                184644        184644
# 3                 105809                105809        105809
# 4                 116958                116958        116958
# 5                 110474                110474        110474
# 6                 146047                146047        146047
# 7                 164149                164149        164149
# 8                 490166                490166        490166
# None              531990                531990        531990
# seldom            338963                338963        338963
#
#         RETAIL_STORE_CHURN_FLAG  RETAIL_STORE_CHURN_DEPUTY_FALG  SPAUTH_IND
# Groups
# 1                        407597                          407597      407597
# 2                        184644                          184644      184644
# 3                        105809                          105809      105809
# 4                        116958                          116958      116958
# 5                        110474                          110474      110474
# 6                        146047                          146047      146047
# 7                        164149                          164149      164149
# 8                        490166                          490166      490166
# None                     531990                          531990      531990
# seldom                   338963                          338963      338963
#
# [10 rows x 133 columns]

# %% [markdown]
# # save numeric data

# %%
path = "./marketing_analyze/"
out_filename = path + "april_marketing_anylze_numeric_and_bool_forlog10"
save_dataframe(numeric_df, out_filename)
